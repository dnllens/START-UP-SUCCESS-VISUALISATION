# %% [markdown]
# # NEW STARTUP CODES

# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.linear_model, sklearn.datasets 
from sklearn import kernel_ridge 
print ("Ready")
# Out:
# Ready

# %%
from IPython.display import HTML
def pretty_print_df(value_counts_):
  "Quick function to display value counts more nicely"
  display(HTML(pd.DataFrame(value_counts_).to_html()))

# %% [markdown]
# # LOADING THE DATASET

# %%
url = "./Dataset/big_startup_secsees_dataset.csv" # Creating a path to the file

df = pd.read_csv (url, delimiter=",")

df.head() #Visualising
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0               1         NaN       2015-01-05      2015-01-05
# 1               2  2014-09-04       2014-03-01      2014-10-14
# 2               1         NaN       2014-01-30      2014-01-30
# 3               1  2007-01-01       2008-03-19      2008-03-19
# 4               1  2010-01-01       2014-07-24      2014-07-24

# %%
df.tail()
# Out:
#                                                permalink  \
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                                /organization/Áeron
# 66366                              /organization/Ôasys-2
# 66367  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
#
#                                              name            homepage_url  \
# 66363               ZZNode Science and Technology   http://www.zznode.com
# 66364                       Zzzzapp Wireless ltd.  http://www.zzzzapp.com
# 66365                                       ÁERON    http://www.aeron.hu/
# 66366                                       Ôasys    http://www.oasys.io/
# 66367  İnovatiff Reklam ve Tanıtım Hizmetleri Tic    http://inovatiff.com
#
#                                            category_list funding_total_usd  \
# 66363                                Enterprise Software           1587301
# 66364        Advertising|Mobile|Web Development|Wireless            114304
# 66365                                                NaN                 -
# 66366  Consumer Electronics|Internet of Things|Teleco...             18192
# 66367                 Consumer Goods|E-Commerce|Internet             14851
#
#           status country_code state_code       region           city  \
# 66363  operating          CHN         22      Beijing        Beijing
# 66364  operating          HRV         15        Split          Split
# 66365  operating          NaN        NaN          NaN            NaN
# 66366  operating          USA         CA  SF Bay Area  San Francisco
# 66367  operating          NaN        NaN          NaN            NaN
#
#        funding_rounds  founded_at first_funding_at last_funding_at
# 66363               1         NaN       2012-04-01      2012-04-01
# 66364               4  2012-05-13       2011-11-01      2014-03-01
# 66365               1  2011-01-01       2014-08-01      2014-08-01
# 66366               1  2014-01-01       2015-01-01      2015-01-01
# 66367               1         NaN       2013-10-01      2013-10-01

# %% [markdown]
# # INSPECTING THE DATA

# %%
# shape of dataset: 
print(df.shape)

# list of column titles 
print(df.columns)
# Out:
# (66368, 14)
# Index(['permalink', 'name', 'homepage_url', 'category_list',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'first_funding_at',
#        'last_funding_at'],
#       dtype='object')

# %%
# list of column (field) data types
print(df.dtypes)
# Out:
# permalink            object
# name                 object
# homepage_url         object
# category_list        object
# funding_total_usd    object
# status               object
# country_code         object
# state_code           object
# region               object
# city                 object
# funding_rounds        int64
# founded_at           object
# first_funding_at     object
# last_funding_at      object
# dtype: object

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# # PRE PROCESSING

# %%
# !pip install squarify
import squarify    
# !pip install geopandas
# Out:
# Requirement already satisfied: squarify in /Users/mac/anaconda3/lib/python3.10/site-packages (0.4.3)
# Requirement already satisfied: geopandas in /Users/mac/anaconda3/lib/python3.10/site-packages (0.13.0)
# Requirement already satisfied: shapely>=1.7.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in /Users/mac/anaconda3/lib/python3.10/site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: pyproj>=3.0.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: pandas>=1.1.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: packaging in /Users/mac/anaconda3/lib/python3.10/site-packages (from geopandas) (22.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (22.1.0)
# Requirement already satisfied: certifi in /Users/mac/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: cligj>=0.5 in /Users/mac/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /Users/mac/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: click~=8.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas) (1.23.5)

# %%
# Summary statistics for numerical features
df.describe()
# Out:
#        funding_rounds
# count    66368.000000
# mean         1.732522
# std          1.360251
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000

# %% [markdown]
# # VIEWING SOME CATEGORICAL COLUMN

# %%
# let's list some categorical features
categorical_columns= [  
        'status'
       ]

# let's get the categories and their count for each feature
for col in categorical_columns:
  print(f"Categories and number of occurrences for '{col}'")
  pretty_print_df(df[col].value_counts())
  print()
# Out:
# Categories and number of occurrences for 'status'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>operating</th>
#       <td>53034</td>
#     </tr>
#     <tr>
#       <th>closed</th>
#       <td>6238</td>
#     </tr>
#     <tr>
#       <th>acquired</th>
#       <td>5549</td>
#     </tr>
#     <tr>
#       <th>ipo</th>
#       <td>1547</td>
#     </tr>
#   </tbody>
# </table>

# %%
categorical_columns= [  
        'region'
       ]

# let's get the categories and their count for each feature
for col in categorical_columns:
  print(f"Categories and number of occurrences for '{col}'")
  pretty_print_df(df[col].value_counts())
  print()
# Out:
# Categories and number of occurrences for 'region'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SF Bay Area</th>
#       <td>8804</td>
#     </tr>
#     <tr>
#       <th>New York City</th>
#       <td>3528</td>
#     </tr>
#     <tr>
#       <th>Boston</th>
#       <td>2378</td>
#     </tr>
#     <tr>
#       <th>London</th>
#       <td>2345</td>
#     </tr>
#     <tr>
#       <th>Los Angeles</th>
#       <td>1877</td>
#     </tr>
#     <tr>
#       <th>Seattle</th>
#       <td>1207</td>
#     </tr>
#     <tr>
#       <th>Washington, D.C.</th>
#       <td>1035</td>
#     </tr>
#     <tr>
#       <th>Chicago</th>
#       <td>980</td>
#     </tr>
#     <tr>
#       <th>San Diego</th>
#       <td>899</td>
#     </tr>
#     <tr>
#       <th>Denver</th>
#       <td>831</td>
#     </tr>
#     <tr>
#       <th>Austin</th>
#       <td>825</td>
#     </tr>
#     <tr>
#       <th>Toronto</th>
#       <td>747</td>
#     </tr>
#     <tr>
#       <th>Tel Aviv</th>
#       <td>718</td>
#     </tr>
#     <tr>
#       <th>Paris</th>
#       <td>678</td>
#     </tr>
#     <tr>
#       <th>Atlanta</th>
#       <td>664</td>
#     </tr>
#     <tr>
#       <th>Dallas</th>
#       <td>613</td>
#     </tr>
#     <tr>
#       <th>Newark</th>
#       <td>603</td>
#     </tr>
#     <tr>
#       <th>Beijing</th>
#       <td>576</td>
#     </tr>
#     <tr>
#       <th>Philadelphia</th>
#       <td>549</td>
#     </tr>
#     <tr>
#       <th>Anaheim</th>
#       <td>499</td>
#     </tr>
#     <tr>
#       <th>Salt Lake City</th>
#       <td>442</td>
#     </tr>
#     <tr>
#       <th>Singapore</th>
#       <td>438</td>
#     </tr>
#     <tr>
#       <th>Bangalore</th>
#       <td>432</td>
#     </tr>
#     <tr>
#       <th>Raleigh</th>
#       <td>410</td>
#     </tr>
#     <tr>
#       <th>Minneapolis</th>
#       <td>396</td>
#     </tr>
#     <tr>
#       <th>Houston</th>
#       <td>388</td>
#     </tr>
#     <tr>
#       <th>Hartford</th>
#       <td>373</td>
#     </tr>
#     <tr>
#       <th>New Delhi</th>
#       <td>366</td>
#     </tr>
#     <tr>
#       <th>Phoenix</th>
#       <td>358</td>
#     </tr>
#     <tr>
#       <th>Shanghai</th>
#       <td>346</td>
#     </tr>
#     <tr>
#       <th>Moscow</th>
#       <td>333</td>
#     </tr>
#     <tr>
#       <th>Portland, Oregon</th>
#       <td>332</td>
#     </tr>
#     <tr>
#       <th>Santiago</th>
#       <td>327</td>
#     </tr>
#     <tr>
#       <th>Vancouver</th>
#       <td>326</td>
#     </tr>
#     <tr>
#       <th>Detroit</th>
#       <td>326</td>
#     </tr>
#     <tr>
#       <th>Tokyo</th>
#       <td>309</td>
#     </tr>
#     <tr>
#       <th>Dublin</th>
#       <td>303</td>
#     </tr>
#     <tr>
#       <th>Seoul</th>
#       <td>302</td>
#     </tr>
#     <tr>
#       <th>Pittsburgh</th>
#       <td>299</td>
#     </tr>
#     <tr>
#       <th>Mumbai</th>
#       <td>295</td>
#     </tr>
#     <tr>
#       <th>Baltimore</th>
#       <td>293</td>
#     </tr>
#     <tr>
#       <th>Nashville</th>
#       <td>290</td>
#     </tr>
#     <tr>
#       <th>Barcelona</th>
#       <td>276</td>
#     </tr>
#     <tr>
#       <th>Miami</th>
#       <td>262</td>
#     </tr>
#     <tr>
#       <th>Berlin</th>
#       <td>253</td>
#     </tr>
#     <tr>
#       <th>Stockholm</th>
#       <td>245</td>
#     </tr>
#     <tr>
#       <th>Montreal</th>
#       <td>245</td>
#     </tr>
#     <tr>
#       <th>Madrid</th>
#       <td>237</td>
#     </tr>
#     <tr>
#       <th>Amsterdam</th>
#       <td>236</td>
#     </tr>
#     <tr>
#       <th>GBR - Other</th>
#       <td>232</td>
#     </tr>
#     <tr>
#       <th>Tampa</th>
#       <td>225</td>
#     </tr>
#     <tr>
#       <th>Sydney</th>
#       <td>222</td>
#     </tr>
#     <tr>
#       <th>Cleveland</th>
#       <td>220</td>
#     </tr>
#     <tr>
#       <th>Las Vegas</th>
#       <td>218</td>
#     </tr>
#     <tr>
#       <th>Sao Paulo</th>
#       <td>205</td>
#     </tr>
#     <tr>
#       <th>St. Louis</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>Helsinki</th>
#       <td>197</td>
#     </tr>
#     <tr>
#       <th>Indianapolis</th>
#       <td>189</td>
#     </tr>
#     <tr>
#       <th>Munich</th>
#       <td>176</td>
#     </tr>
#     <tr>
#       <th>Hong Kong</th>
#       <td>171</td>
#     </tr>
#     <tr>
#       <th>Palm Beaches</th>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>Copenhagen</th>
#       <td>165</td>
#     </tr>
#     <tr>
#       <th>Buenos Aires</th>
#       <td>165</td>
#     </tr>
#     <tr>
#       <th>Columbus, Ohio</th>
#       <td>157</td>
#     </tr>
#     <tr>
#       <th>Ft. Lauderdale</th>
#       <td>157</td>
#     </tr>
#     <tr>
#       <th>FRA - Other</th>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>Cincinnati</th>
#       <td>154</td>
#     </tr>
#     <tr>
#       <th>Orlando</th>
#       <td>148</td>
#     </tr>
#     <tr>
#       <th>DEU - Other</th>
#       <td>146</td>
#     </tr>
#     <tr>
#       <th>Brussels</th>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>Santa Barbara</th>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>CHN - Other</th>
#       <td>131</td>
#     </tr>
#     <tr>
#       <th>Kansas City</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>Sacramento</th>
#       <td>129</td>
#     </tr>
#     <tr>
#       <th>Shenzhen</th>
#       <td>128</td>
#     </tr>
#     <tr>
#       <th>Long Island</th>
#       <td>126</td>
#     </tr>
#     <tr>
#       <th>Melbourne</th>
#       <td>121</td>
#     </tr>
#     <tr>
#       <th>Madison</th>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>Manchester, New Hampshire</th>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>Istanbul</th>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>Orange County, California</th>
#       <td>117</td>
#     </tr>
#     <tr>
#       <th>Ottawa</th>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>Zurich</th>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>Ontario - Inland Empire</th>
#       <td>113</td>
#     </tr>
#     <tr>
#       <th>CA - Other</th>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>Milan</th>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>Providence</th>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>Charlotte</th>
#       <td>106</td>
#     </tr>
#     <tr>
#       <th>Omaha</th>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>Fayetteville</th>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>NY - Other</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>Frankfurt</th>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>Hamburg</th>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>San Antonio</th>
#       <td>98</td>
#     </tr>
#     <tr>
#       <th>Calgary</th>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>Birmingham</th>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>Memphis</th>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>Vienna</th>
#       <td>93</td>
#     </tr>
#     <tr>
#       <th>NLD - Other</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>Sofia</th>
#       <td>91</td>
#     </tr>
#     <tr>
#       <th>Rio de Janeiro</th>
#       <td>91</td>
#     </tr>
#     <tr>
#       <th>Dubai</th>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>Wilmington, Delaware</th>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>Hyderabad</th>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>Albuquerque</th>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>Napa Valley</th>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>Mexico City</th>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>Jakarta</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>Malmo</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>NJ - Other</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>Worcester</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>Edinburgh</th>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th>Milwaukee</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>Chennai</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>Richmond</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>Jacksonville</th>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>BRA - Other</th>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>CHE - Other</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>Kuala Lumpur</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>Louisville</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>Oslo</th>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>Rochester, New York</th>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>DNK - Other</th>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>ITA - Other</th>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>Litt

# %%
categorical_columns= [  
        'country_code'
       ]

# let's get the categories and their count for each feature
for col in categorical_columns:
  print(f"Categories and number of occurrences for '{col}'")
  pretty_print_df(df[col].value_counts())
  print()
# Out:
# Categories and number of occurrences for 'country_code'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country_code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>USA</th>
#       <td>37601</td>
#     </tr>
#     <tr>
#       <th>GBR</th>
#       <td>3688</td>
#     </tr>
#     <tr>
#       <th>CAN</th>
#       <td>1925</td>
#     </tr>
#     <tr>
#       <th>IND</th>
#       <td>1596</td>
#     </tr>
#     <tr>
#       <th>CHN</th>
#       <td>1544</td>
#     </tr>
#     <tr>
#       <th>FRA</th>
#       <td>1135</td>
#     </tr>
#     <tr>
#       <th>DEU</th>
#       <td>1082</td>
#     </tr>
#     <tr>
#       <th>ISR</th>
#       <td>965</td>
#     </tr>
#     <tr>
#       <th>ESP</th>
#       <td>746</td>
#     </tr>
#     <tr>
#       <th>AUS</th>
#       <td>503</td>
#     </tr>
#     <tr>
#       <th>NLD</th>
#       <td>497</td>
#     </tr>
#     <tr>
#       <th>RUS</th>
#       <td>458</td>
#     </tr>
#     <tr>
#       <th>SGP</th>
#       <td>455</td>
#     </tr>
#     <tr>
#       <th>SWE</th>
#       <td>452</td>
#     </tr>
#     <tr>
#       <th>BRA</th>
#       <td>446</td>
#     </tr>
#     <tr>
#       <th>IRL</th>
#       <td>440</td>
#     </tr>
#     <tr>
#       <th>JPN</th>
#       <td>411</td>
#     </tr>
#     <tr>
#       <th>ITA</th>
#       <td>404</td>
#     </tr>
#     <tr>
#       <th>KOR</th>
#       <td>362</td>
#     </tr>
#     <tr>
#       <th>CHE</th>
#       <td>335</td>
#     </tr>
#     <tr>
#       <th>CHL</th>
#       <td>332</td>
#     </tr>
#     <tr>
#       <th>DNK</th>
#       <td>311</td>
#     </tr>
#     <tr>
#       <th>FIN</th>
#       <td>283</td>
#     </tr>
#     <tr>
#       <th>HKG</th>
#       <td>209</td>
#     </tr>
#     <tr>
#       <th>BEL</th>
#       <td>205</td>
#     </tr>
#     <tr>
#       <th>ARG</th>
#       <td>186</td>
#     </tr>
#     <tr>
#       <th>TUR</th>
#       <td>178</td>
#     </tr>
#     <tr>
#       <th>POL</th>
#       <td>150</td>
#     </tr>
#     <tr>
#       <th>MEX</th>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>NOR</th>
#       <td>134</td>
#     </tr>
#     <tr>
#       <th>AUT</th>
#       <td>133</td>
#     </tr>
#     <tr>
#       <th>PRT</th>
#       <td>113</td>
#     </tr>
#     <tr>
#       <th>IDN</th>
#       <td>108</td>
#     </tr>
#     <tr>
#       <th>BGR</th>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>NZL</th>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>ARE</th>
#       <td>94</td>
#     </tr>
#     <tr>
#       <th>ZAF</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>MYS</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>EST</th>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>CZE</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>PHL</th>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>UKR</th>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>NGA</th>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>COL</th>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>TWN</th>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>THA</th>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>HUN</th>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>PER</th>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>LVA</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>LTU</th>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>VNM</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>GRC</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>KEN</th>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>EGY</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>ROM</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>LUX</th>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>PAK</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>JOR</th>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>SVK</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>SVN</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>ISL</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>LBN</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>CYP</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>URY</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>UGA</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>SRB</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>VEN</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>GHA</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>CYM</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>BGD</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>CRI</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>KHM</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>TAN</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>SAU</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>PAN</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>MLT</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>HRV</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>ECU</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>MUS</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>BMU</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>BLR</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>GTM</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>BHR</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>TTO</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>AZE</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>GEO</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>MMR</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>BWA</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>NPL</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>TUN</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>JAM</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>LAO</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>DOM</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>MKD</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>RWA</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>SLV</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>MCO</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>LKA</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>CMR</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>ARM</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>PRI</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>MDA</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>LIE</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>ZWE</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>KWT</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>MOZ</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>MAR</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>CIV</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>PSE</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>HND</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>GIB</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>ZMB</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>NIC</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>BAH</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>ALB</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>BLZ</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>BLM</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>GRD</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>SOM</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>SYC</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>JEY</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>UZB</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>OMN</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>PRY</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>GGY</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>DMA</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>SEN</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>KNA</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>DZA</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>QAT</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>KAZ</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>TGO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BRN</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BRB</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>IRN</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>MNE</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>MAF</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # CONVERTING THE TOTAL FUNDING TO AN INTEGER FORMAT

# %%
df.loc[df.funding_total_usd=='-','funding_total_usd'] = np.nan

# %%
# Convert funding_total_usd column from object to integer data type
df['funding_total_usd'] = df['funding_total_usd'].astype(float)

# %%
df.describe()
# Out:
#        funding_total_usd  funding_rounds
# count       5.358300e+04    66368.000000
# mean        1.847860e+07        1.732522
# std         1.880133e+08        1.360251
# min         1.000000e+00        1.000000
# 25%         3.356235e+05        1.000000
# 50%         2.000000e+06        1.000000
# 75%         1.000000e+07        2.000000
# max         3.007950e+10       19.000000

# %% [markdown]
# # VIEWING THE NUMBER OF STARTUPS BY STATUS

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=df['status'].value_counts().index,y=df['status'].value_counts())
plt.title('Number of startups by status',size=18)
plt.ylabel('Number of startups',size=12)
# Out:
# Text(0, 0.5, 'Number of startups')

# %% [markdown]
# # BY FUNDING ROUNDS

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['funding_rounds'].value_counts().index, y=df['funding_rounds'].value_counts(), color ='#3c1273')
plt.title('Number of startups by funding_rounds',size=18)
plt.ylabel('Number of startups',size=14)
plt.xlabel('Number of funding_rounds', size=14)
plt.grid(axis='y')
plt.yscale('log')

def addlabels(x,y):
    for i in x:
        plt.text(i-1.25,y[i],y[i])

addlabels(df['funding_rounds'].value_counts().index,df['funding_rounds'].value_counts())

# %% [markdown]
# #### seems like all the startup has at least one funding round

# %% [markdown]
# # HANDLING MISSING DATA

# %%
df.isna().sum()
# Out:
# permalink                0
# name                     1
# homepage_url          5058
# category_list         3148
# funding_total_usd    12785
# status                   0
# country_code          6958
# state_code            8547
# region                8030
# city                  8028
# funding_rounds           0
# founded_at           15221
# first_funding_at        24
# last_funding_at          0
# dtype: int64

# %% [markdown]
# # SIMPLE IMPUTER FOR NUMERIC DATA

# %%
# handling missing data
from sklearn.impute import SimpleImputer 

df =  df.copy()

# 1. Imputer
imptr_num = SimpleImputer(missing_values = np.nan, strategy = 'median')  

# 2. Fit the imputer object to the feature matrix (only for numeric features)
numerical_columns = ['funding_total_usd']
imptr_num = imptr_num.fit(df[numerical_columns]) # fit the data to estimate the parameters (here, the average value)

# 3. Call Transform to replace missing data in train_dataset (on specific columns) by the mean of the column to which that missing data belongs to
df[numerical_columns] = \
  imptr_num.transform(df[numerical_columns]) # apply the transformation using the parameters estimated above

# note column ApplicantIncome in the first row --> before it was a missing value!
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list  funding_total_usd  \
# 0                                              Media         10000000.0
# 1  Application Platforms|Real Time|Social Network...           700000.0
# 2                                  Apps|Games|Mobile          3406878.0
# 3                                        Curated Web          2000000.0
# 4                                           Software          2000000.0
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0               1         NaN       2015-01-05      2015-01-05
# 1               2  2014-09-04       2014-03-01      2014-10-14
# 2               1         NaN       2014-01-30      2014-01-30
# 3               1  2007-01-01       2008-03-19      2008-03-19
# 4               1  2010-01-01       2014-07-24      2014-07-24

# %% [markdown]
# # FILLING THE COUNTRY CODE WITH RANDOM SAMPLE IMPUTATION

# %%
# Let's see the status of startups depending on the country
country = []

for i in df.country_code:
  if not isinstance(i,str):
    country.append(np.random.choice(df.country_code[df.country_code.notnull()]))
  else:
    country.append(i)

df['country'] = country

# %% [markdown]
# # CREATING A ONE HOT ENCODING FOR THE STATUS

# %%
status = []

for i in df['status']:
    if i in ['acquired','ipo']:
        status.append('high')
    elif i == 'closed':
        status.append('fail')
    else:
        status.append('mid')
        
df['status_class'] = status

# %%
status_class = pd.get_dummies(df['status_class'])
df = pd.concat([df,status_class],axis=1)
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list  funding_total_usd  \
# 0                                              Media         10000000.0
# 1  Application Platforms|Real Time|Social Network...           700000.0
# 2                                  Apps|Games|Mobile          3406878.0
# 3                                        Curated Web          2000000.0
# 4                                           Software          2000000.0
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at country  \
# 0               1         NaN       2015-01-05      2015-01-05     IND
# 1               2  2014-09-04       2014-03-01      2014-10-14     USA
# 2               1         NaN       2014-01-30      2014-01-30     FRA
# 3               1  2007-01-01       2008-03-19      2008-03-19     CHN
# 4               1  2010-01-01       2014-07-24      2014-07-24     USA
#
#   status_class  fail  high  mid
# 0          mid     0     0    1
# 1          mid     0     0    1
# 2          mid     0     0    1
# 3          mid     0     0    1
# 4          mid     0     0    1

# %% [markdown]
# # CREATING A YEARS COLUMN

# %%
years = []

for fou, first in zip(df.founded_at, df.first_funding_at):
  if isinstance(fou,str):
    years.append(int(fou.split('-')[0]))
  elif not isinstance(fou,str) and isinstance(first,str):
    years.append(int(first.split('-')[0]))
  else:
    date = int(np.random.choice(df.founded_at[df.founded_at.notnull()]).split('-')[0])
    years.append(date)

df['year'] = years
df[df.founded_at.isnull()].head()
# Out:
#                               permalink                    name  \
# 0                   /organization/-fame                   #fame
# 2   /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 5      /organization/01games-technology      01Games Technology
# 10                /organization/1-4-all                 1-4 All
# 28               /organization/100du-tv                100du.tv
#
#               homepage_url                 category_list  funding_total_usd  \
# 0       http://livfame.com                         Media         10000000.0
# 2      http://oneofthem.jp             Apps|Games|Mobile          3406878.0
# 5   http://www.01games.hk/                         Games            41250.0
# 10                     NaN  Entertainment|Games|Software          2000000.0
# 28    http://www.100du.com                   Hospitality          3000000.0
#
#        status country_code state_code      region               city  \
# 0   operating          IND         16      Mumbai             Mumbai
# 2   operating          NaN        NaN         NaN                NaN
# 5   operating          HKG        NaN   Hong Kong          Hong Kong
# 10  operating          USA         NC  NC - Other  Connellys Springs
# 28  operating          CHN         23    Shanghai           Shanghai
#
#     funding_rounds founded_at first_funding_at last_funding_at country  \
# 0                1        NaN       2015-01-05      2015-01-05     IND
# 2                1        NaN       2014-01-30      2014-01-30     FRA
# 5                1        NaN       2014-07-01      2014-07-01     HKG
# 10               1        NaN       2013-04-21      2013-04-21     USA
# 28               2        NaN       2008-01-07      2010-08-13     CHN
#
#    status_class  fail  high  mid  year
# 0           mid     0     0    1  2015
# 2           mid     0     0    1  2014
# 5           mid     0     0    1  2014
# 10          mid     0     0    1  2013
# 28          mid     0     0    1  2008

# %% [markdown]
# # SIMPLIFY THE CATEGORY COLUMN LIST

# %%
main_category = []

for i in df['category_list']:
    if not isinstance(i,str):
      main_category.append('Other')
    else:
      main_category.append(i.split('|')[0])

df['main_category'] = main_category
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list  funding_total_usd  \
# 0                                              Media         10000000.0
# 1  Application Platforms|Real Time|Social Network...           700000.0
# 2                                  Apps|Games|Mobile          3406878.0
# 3                                        Curated Web          2000000.0
# 4                                           Software          2000000.0
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    ...  founded_at first_funding_at last_funding_at country status_class fail  \
# 0  ...         NaN       2015-01-05      2015-01-05     IND          mid    0
# 1  ...  2014-09-04       2014-03-01      2014-10-14     USA          mid    0
# 2  ...         NaN       2014-01-30      2014-01-30     FRA          mid    0
# 3  ...  2007-01-01       2008-03-19      2008-03-19     CHN          mid    0
# 4  ...  2010-01-01       2014-07-24      2014-07-24     USA          mid    0
#
#    high  mid  year          main_category
# 0     0    1  2015                  Media
# 1     0    1  2014  Application Platforms
# 2     0    1  2014                   Apps
# 3     0    1  2007            Curated Web
# 4     0    1  2010               Software
#
# [5 rows x 21 columns]

# %%
# let's list all categorical features
categorical_columns= [  
        'main_category'
       ]

# let's get the categories and their count for each feature
for col in categorical_columns:
  print(f"Categories and number of occurrences for '{col}'")
  pretty_print_df(df[col].value_counts())
  print()
# Out:
# Categories and number of occurrences for 'main_category'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>main_category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Biotechnology</th>
#       <td>4468</td>
#     </tr>
#     <tr>
#       <th>Software</th>
#       <td>4144</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>3148</td>
#     </tr>
#     <tr>
#       <th>E-Commerce</th>
#       <td>2752</td>
#     </tr>
#     <tr>
#       <th>Advertising</th>
#       <td>2397</td>
#     </tr>
#     <tr>
#       <th>Curated Web</th>
#       <td>2197</td>
#     </tr>
#     <tr>
#       <th>Mobile</th>
#       <td>1776</td>
#     </tr>
#     <tr>
#       <th>Analytics</th>
#       <td>1641</td>
#     </tr>
#     <tr>
#       <th>Apps</th>
#       <td>1502</td>
#     </tr>
#     <tr>
#       <th>Health Care</th>
#       <td>1430</td>
#     </tr>
#     <tr>
#       <th>Clean Technology</th>
#       <td>1414</td>
#     </tr>
#     <tr>
#       <th>Enterprise Software</th>
#       <td>1365</td>
#     </tr>
#     <tr>
#       <th>Games</th>
#       <td>1281</td>
#     </tr>
#     <tr>
#       <th>Health and Wellness</th>
#       <td>1210</td>
#     </tr>
#     <tr>
#       <th>Hardware + Software</th>
#       <td>1119</td>
#     </tr>
#     <tr>
#       <th>Finance</th>
#       <td>1114</td>
#     </tr>
#     <tr>
#       <th>Education</th>
#       <td>1060</td>
#     </tr>
#     <tr>
#       <th>Manufacturing</th>
#       <td>887</td>
#     </tr>
#     <tr>
#       <th>Consulting</th>
#       <td>720</td>
#     </tr>
#     <tr>
#       <th>Internet</th>
#       <td>638</td>
#     </tr>
#     <tr>
#       <th>Cloud Computing</th>
#       <td>606</td>
#     </tr>
#     <tr>
#       <th>Entertainment</th>
#       <td>572</td>
#     </tr>
#     <tr>
#       <th>Android</th>
#       <td>545</td>
#     </tr>
#     <tr>
#       <th>Semiconductors</th>
#       <td>534</td>
#     </tr>
#     <tr>
#       <th>Hospitality</th>
#       <td>507</td>
#     </tr>
#     <tr>
#       <th>Social Media</th>
#       <td>496</td>
#     </tr>
#     <tr>
#       <th>Real Estate</th>
#       <td>481</td>
#     </tr>
#     <tr>
#       <th>Automotive</th>
#       <td>472</td>
#     </tr>
#     <tr>
#       <th>Fashion</th>
#       <td>471</td>
#     </tr>
#     <tr>
#       <th>Security</th>
#       <td>464</td>
#     </tr>
#     <tr>
#       <th>Big Data</th>
#       <td>411</td>
#     </tr>
#     <tr>
#       <th>Business Services</th>
#       <td>401</td>
#     </tr>
#     <tr>
#       <th>Information Technology</th>
#       <td>376</td>
#     </tr>
#     <tr>
#       <th>Design</th>
#       <td>371</td>
#     </tr>
#     <tr>
#       <th>Web Hosting</th>
#       <td>362</td>
#     </tr>
#     <tr>
#       <th>Consumer Electronics</th>
#       <td>329</td>
#     </tr>
#     <tr>
#       <th>Medical</th>
#       <td>322</td>
#     </tr>
#     <tr>
#       <th>B2B</th>
#       <td>320</td>
#     </tr>
#     <tr>
#       <th>Financial Services</th>
#       <td>318</td>
#     </tr>
#     <tr>
#       <th>Consumer Goods</th>
#       <td>313</td>
#     </tr>
#     <tr>
#       <th>EdTech</th>
#       <td>304</td>
#     </tr>
#     <tr>
#       <th>Collaboration</th>
#       <td>297</td>
#     </tr>
#     <tr>
#       <th>Technology</th>
#       <td>291</td>
#     </tr>
#     <tr>
#       <th>Content</th>
#       <td>274</td>
#     </tr>
#     <tr>
#       <th>Messaging</th>
#       <td>273</td>
#     </tr>
#     <tr>
#       <th>Music</th>
#       <td>257</td>
#     </tr>
#     <tr>
#       <th>News</th>
#       <td>253</td>
#     </tr>
#     <tr>
#       <th>Digital Media</th>
#       <td>247</td>
#     </tr>
#     <tr>
#       <th>Travel</th>
#       <td>247</td>
#     </tr>
#     <tr>
#       <th>Big Data Analytics</th>
#       <td>241</td>
#     </tr>
#     <tr>
#       <th>Application Platforms</th>
#       <td>230</td>
#     </tr>
#     <tr>
#       <th>Media</th>
#       <td>230</td>
#     </tr>
#     <tr>
#       <th>Networking</th>
#       <td>227</td>
#     </tr>
#     <tr>
#       <th>Fitness</th>
#       <td>212</td>
#     </tr>
#     <tr>
#       <th>Brand Marketing</th>
#       <td>210</td>
#     </tr>
#     <tr>
#       <th>Computers</th>
#       <td>209</td>
#     </tr>
#     <tr>
#       <th>Energy</th>
#       <td>201</td>
#     </tr>
#     <tr>
#       <th>Services</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>Sports</th>
#       <td>196</td>
#     </tr>
#     <tr>
#       <th>Photography</th>
#       <td>191</td>
#     </tr>
#     <tr>
#       <th>Public Relations</th>
#       <td>188</td>
#     </tr>
#     <tr>
#       <th>Search</th>
#       <td>185</td>
#     </tr>
#     <tr>
#       <th>Customer Service</th>
#       <td>178</td>
#     </tr>
#     <tr>
#       <th>Medical Devices</th>
#       <td>177</td>
#     </tr>
#     <tr>
#       <th>Marketplaces</th>
#       <td>174</td>
#     </tr>
#     <tr>
#       <th>Consumers</th>
#       <td>173</td>
#     </tr>
#     <tr>
#       <th>Communities</th>
#       <td>172</td>
#     </tr>
#     <tr>
#       <th>Beauty</th>
#       <td>172</td>
#     </tr>
#     <tr>
#       <th>Crowdfunding</th>
#       <td>169</td>
#     </tr>
#     <tr>
#       <th>Art</th>
#       <td>163</td>
#     </tr>
#     <tr>
#       <th>Pharmaceuticals</th>
#       <td>163</td>
#     </tr>
#     <tr>
#       <th>Crowdsourcing</th>
#       <td>159</td>
#     </tr>
#     <tr>
#       <th>Artificial Intelligence</th>
#       <td>159</td>
#     </tr>
#     <tr>
#       <th>Banking</th>
#       <td>157</td>
#     </tr>
#     <tr>
#       <th>Electronics</th>
#       <td>154</td>
#     </tr>
#     <tr>
#       <th>Enterprises</th>
#       <td>150</td>
#     </tr>
#     <tr>
#       <th>3D</th>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>Agriculture</th>
#       <td>148</td>
#     </tr>
#     <tr>
#       <th>Transportation</th>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>Bitcoin</th>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>CRM</th>
#       <td>143</td>
#     </tr>
#     <tr>
#       <th>Events</th>
#       <td>142</td>
#     </tr>
#     <tr>
#       <th>Audio</th>
#       <td>139</td>
#     </tr>
#     <tr>
#       <th>Delivery</th>
#       <td>136</td>
#     </tr>
#     <tr>
#       <th>Accounting</th>
#       <td>134</td>
#     </tr>
#     <tr>
#       <th>Food Processing</th>
#       <td>132</td>
#     </tr>
#     <tr>
#       <th>Human Resources</th>
#       <td>131</td>
#     </tr>
#     <tr>
#       <th>Blogging Platforms</th>
#       <td>128</td>
#     </tr>
#     <tr>
#       <th>Aerospace</th>
#       <td>126</td>
#     </tr>
#     <tr>
#       <th>Career Management</th>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>All Students</th>
#       <td>117</td>
#     </tr>
#     <tr>
#       <th>Nanotechnology</th>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>Cloud Data Services</th>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>Public Transportation</th>
#       <td>115</td>
#     </tr>
#     <tr>
#       <th>SaaS</th>
#       <td>115</td>
#     </tr>
#     <tr>
#       <th>Bio-Pharm</th>
#       <td>113</td>
#     </tr>
#     <tr>
#       <th>Broadcasting</th>
#       <td>111</td>
#     </tr>
#     <tr>
#       <th>Nonprofits</th>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>Chat</th>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>Hardware</th>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>Ad Targeting</th>
#       <td>107</td>
#     </tr>
#     <tr>
#       <th>Databases</th>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>Telecommunications</th>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>Colleges</th>
#       <td>98</td>
#     </tr>
#     <tr>
#       <th>Legal</th>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>Clean Energy</th>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>Facebook Applications</th>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>Information Services</th>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>3D Printing</th>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>Construction</th>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>Retail</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>Coupons</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>Location Based Services</th>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>Collaborative Consumption</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>Cyber Security</th>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>Business Intelligence</th>
#       <td>82</td>
#     </tr>
#     <tr>
#       <th>Advertising Platforms</th>
#       <td>82</td>
#     </tr>
#     <tr>
#       <th>Internet of Things</th>
#       <td>82</td>
#     </tr>
#     <tr>
#       <th>Health Care Information Technology</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>Game</th>
#       <td>80<

# %% [markdown]
# # CREATING A LOCATION TABLE

# %%
# Fill NaNs with empty string
df['region'] = df['region'].fillna("")
df['city'] = df['city'].fillna("")

# Combine the 'region' and 'city' columns, without repeating when they are the same
df['location'] = df.apply(lambda row: row['region'] if row['region'] == row['city'] else row['region'] + ', ' + row['city'], axis=1)
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list  funding_total_usd  \
# 0                                              Media         10000000.0
# 1  Application Platforms|Real Time|Social Network...           700000.0
# 2                                  Apps|Games|Mobile          3406878.0
# 3                                        Curated Web          2000000.0
# 4                                           Software          2000000.0
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    ...  first_funding_at last_funding_at country status_class fail high  mid  \
# 0  ...        2015-01-05      2015-01-05     IND          mid    0    0    1
# 1  ...        2014-03-01      2014-10-14     USA          mid    0    0    1
# 2  ...        2014-01-30      2014-01-30     FRA          mid    0    0    1
# 3  ...        2008-03-19      2008-03-19     CHN          mid    0    0    1
# 4  ...        2014-07-24      2014-07-24     USA          mid    0    0    1
#
#    year          main_category                          location
# 0  2015                  Media                            Mumbai
# 1  2014  Application Platforms         DE - Other, Delaware City
# 2  2014                   Apps
# 3  2007            Curated Web                           Beijing
# 4  2010               Software  Springfield, Illinois, Champaign
#
# [5 rows x 22 columns]

# %%
df['location'] = df['location'].replace("", np.nan)
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list  funding_total_usd  \
# 0                                              Media         10000000.0
# 1  Application Platforms|Real Time|Social Network...           700000.0
# 2                                  Apps|Games|Mobile          3406878.0
# 3                                        Curated Web          2000000.0
# 4                                           Software          2000000.0
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    ...  first_funding_at last_funding_at country status_class fail high  mid  \
# 0  ...        2015-01-05      2015-01-05     IND          mid    0    0    1
# 1  ...        2014-03-01      2014-10-14     USA          mid    0    0    1
# 2  ...        2014-01-30      2014-01-30     FRA          mid    0    0    1
# 3  ...        2008-03-19      2008-03-19     CHN          mid    0    0    1
# 4  ...        2014-07-24      2014-07-24     USA          mid    0    0    1
#
#    year          main_category                          location
# 0  2015                  Media                            Mumbai
# 1  2014  Application Platforms         DE - Other, Delaware City
# 2  2014                   Apps                               NaN
# 3  2007            Curated Web                           Beijing
# 4  2010               Software  Springfield, Illinois, Champaign
#
# [5 rows x 22 columns]

# %% [markdown]
# # SELECT ONLY THE COLUMN NEEDED FOR ANALYSIS

# %%
df = df[['name','country','year','location','main_category','funding_total_usd','funding_rounds',
               'first_funding_at','last_funding_at','status','status_class','fail','high','mid']]
df.head()
# Out:
#                      name country  year                          location  \
# 0                   #fame     IND  2015                            Mumbai
# 1                :Qounter     USA  2014         DE - Other, Delaware City
# 2  (THE) ONE of THEM,Inc.     FRA  2014                               NaN
# 3                 0-6.com     CHN  2007                           Beijing
# 4        004 Technologies     USA  2010  Springfield, Illinois, Champaign
#
#            main_category  funding_total_usd  funding_rounds first_funding_at  \
# 0                  Media         10000000.0               1       2015-01-05
# 1  Application Platforms           700000.0               2       2014-03-01
# 2                   Apps          3406878.0               1       2014-01-30
# 3            Curated Web          2000000.0               1       2008-03-19
# 4               Software          2000000.0               1       2014-07-24
#
#   last_funding_at     status status_class  fail  high  mid
# 0      2015-01-05  operating          mid     0     0    1
# 1      2014-10-14  operating          mid     0     0    1
# 2      2014-01-30  operating          mid     0     0    1
# 3      2008-03-19  operating          mid     0     0    1
# 4      2014-07-24  operating          mid     0     0    1

# %%
df.isna().sum()
# Out:
# name                    1
# country                 0
# year                    0
# location             8028
# main_category           0
# funding_total_usd       0
# funding_rounds          0
# first_funding_at       24
# last_funding_at         0
# status                  0
# status_class            0
# fail                    0
# high                    0
# mid                     0
# dtype: int64

# %% [markdown]
# ## How many startups achieved the high success?

# %%
high_success_ratio = df.high.mean()*100
print(f'{df.high[df.high == 1].count()} startups reach high success, what means {high_success_ratio:.2f}% of total')
# Out:
# 7096 startups reach high success, what means 10.69% of total

# %% [markdown]
# ## How many startups achieved the mid success?

# %%
mid_success_ratio = df.mid.mean()*100
print(f'{df.mid[df.mid == 1].count()} startups reach mid success, what means {mid_success_ratio:.2f}% of total')
# Out:
# 53034 startups reach mid success, what means 79.91% of total

# %% [markdown]
# ## How many startups failed?

# %%
fail_ratio = df.fail.mean()*100
print(f'{df.fail[df.fail == 1].count()} startups fail, what means {fail_ratio:.2f}% of total')
# Out:
# 6238 startups fail, what means 9.40% of total

# %%
plt.style.use('seaborn-pastel')
plt.figure(figsize=(8,6))
plt.title('Viewing startups by status_class')
sns.barplot(x= df.status_class.value_counts().index, y=df.status_class.value_counts())
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i-.20,y[i],y[i])

addlabels(df.status_class.value_counts().index,df.status_class.value_counts())
# Out:
# /var/folders/_1/m8z38xzd6hv4d1hlr0776md00000gn/T/ipykernel_16452/65503107.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %% [markdown]
# # FILTER STARTUPS BY  YEAR
# #### Let's see only the startups founded after 1990, cause we want to see if there's a pattern between the most recent startups

# %%
df = df[(df.year > 1990) & (df.year < 2023)]
df.count().max()
# Out:
# 64859

# %%
def group_by_status(column_name):
  # Group by a feature and calculate the fail/success rate
  group = df.groupby(column_name)[['high','mid','fail']].sum()
  group['total'] = group.sum(axis=1)
  group['high_success_ratio'] = group.high/group.total
  group['mid_success_ratio'] = group.mid/group.total
  group['fail_ratio'] = group.fail/group.total
  return group

# %%
year_status = group_by_status('year')
year_status.sort_values(by='year', ascending=False).head()
# Out:
#       high   mid  fail  total  high_success_ratio  mid_success_ratio  \
# year
# 2016     0     1     1      2            0.000000           0.500000
# 2015    48  2791   621   3460            0.013873           0.806647
# 2014   151  7155   448   7754            0.019474           0.922750
# 2013   172  7297   358   7827            0.021975           0.932286
# 2012   325  7097   509   7931            0.040978           0.894843
#
#       fail_ratio
# year
# 2016    0.500000
# 2015    0.179480
# 2014    0.057777
# 2013    0.045739
# 2012    0.064179

# %% [markdown]
# We can see a very clear outlier, and it corresponds to the year 2016, this is due to the small amount of the sample (only 2 entries), so the percentage is not representative.

# %%
df = df[df.year < 2016]
year_status = year_status[year_status.index < 2016]
plt.figure(figsize=(8,6))
plt.title('Number of startups by status_class after filtering by year', size=16)
sns.barplot(x= df.status_class.value_counts().index, y=df.status_class.value_counts())
addlabels(df.status_class.value_counts().index,df.status_class.value_counts())

# %%
print(f'Number of startups: {df.count().max()}')
print(f'{df.high[df.high == 1].count()} startups reached high success, which is {df.high.mean()*100:.2f}% of the total number')
print(f'{df.mid[df.mid == 1].count()} startups reached mid success, which is  {df.mid.mean()*100:.2f}% of the total number')
print(f'{df.fail[df.fail == 1].count()} startups fail, which is {df.fail.mean()*100:.2f}% of the total number')
# Out:
# Number of startups: 64857
# 6669 startups reached high success, which is 10.28% of the total number
# 52065 startups reached mid success, which is  80.28% of the total number
# 6123 startups fail, which is 9.44% of the total number

# %%
plt.figure(figsize=(12,6))
plt.title('Startups created by year', size=18)
plt.ylabel('Number of startups',size=12)
plt.grid()
sns.lineplot(data=year_status, x=year_status.index, y=year_status.total, linewidth=5)
plt.axvline(x=2008, color="red", label="2008 Recesion",linestyle=':')
plt.axvline(x=2000, color="red", label="2000 Dot-com bubble",linestyle=':')
plt.legend()

# %% [markdown]
# We can see in the trend line that there was a clear upward trend in terms of startup creation, with only two setbacks, located in 2000 and 2008, which makes sense, due to the crisis experienced during those years.
#
# However, we can observe a slight drop in 2014 and a huge drop in 2015. This could be explained by the nature of the dataset and the possible lack of entries in the most recent years, as happened in a more extreme way with 2016.

# %%
plt.figure(figsize=(12,6))
plt.title('Startups created by year', size=18)
plt.ylabel('Status Ratio',size=12)
plt.plot(year_status[year_status.index < 2016].index,year_status[year_status.index < 2016].high_success_ratio,
         label='High Success Ratio',color='#3449eb',linewidth=3)
plt.plot(year_status[year_status.index < 2016].index,year_status[year_status.index < 2016].mid_success_ratio,
         label='Mid Success Ratio',color='#62CB3A',linewidth=3)
plt.plot(year_status[year_status.index < 2016].index,year_status[year_status.index < 2016].fail_ratio,
         label='Fail Ratio',color='#EA664A',linewidth=3)
plt.axvline(x=2008, color="blue", label="2008 Recesion",linestyle=':')
plt.axvline(x=2000, color="blue", label="2000 Dot-com bubble",linestyle=':')
#plt.axhline(df.high.mean(), label='Global Success Ratio', linestyle='-.')
plt.grid()
plt.legend()

# %% [markdown]
# We can see a disturbing trend graph of both the percentage of startups that have succeeded and those that have failed over the years, we can see how in both crises, the trend went through an inflection point, in fact, it is just during the 2008 crisis that both trends intersect.
#
# The most distressing thing of all is The clear downward trend in the success rate of startups since its peak in 1997.

# %% [markdown]
# # Let's visualize how is the behavior of startups depending on the country

# %%
country_status = group_by_status('country')

# Filter by countries with at least 50 startups
countries_most = country_status.total[country_status.total >= 50]
print(f'There are {countries_most.count()} countries with at least 50 startups')
# Out:
# There are 48 countries with at least 50 startups

# %%
# Let's the proportion of the total startupos by countries
countries_analysis = country_status[country_status.total >= 50]
top_ten = countries_analysis.total.sort_values(ascending=False).head(10)
rest_world = pd.Series(countries_analysis.total.sort_values(ascending=False)[11:].sum(axis=0), index=['REST OF WORLD'])
world = top_ten.append(rest_world)

plt.figure(figsize=(12,8))
plt.title('Top 10 countries with more startups vs. Rest of world', size=18)
squarify.plot(sizes=world, label=world.index, color=sns.color_palette("magma",len(world)), alpha = 0.7)
plt.axis('off')
plt.show()
# Out:
# /var/folders/_1/m8z38xzd6hv4d1hlr0776md00000gn/T/ipykernel_16452/4240955786.py:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   world = top_ten.append(rest_world)

# %% [markdown]
# We can see that there is quite a wide difference between the US and the rest of the countries, in fact only the US represents more than 60% of the dataset, and has 10 times more startups than the second (UK) in the sample.

# %%
df_nousa = df[df.country != 'USA']

n = len(['high_success_ratio', 'mid_success_ratio','fail_ratio'])
x = np.arange(n)
width = .25

plt.bar(x, df[['high', 'mid','fail']].mean(), width=width, label='With USA')
plt.bar(x - width, df_nousa[['high','mid','fail']].mean(), width=width, label='Without USA')
plt.title('Status Ratio with USA vs. without', size=16)
plt.xticks(x,['high_success_ratio','mid_success_ratio','fail_ratio'])
plt.legend()
plt.show()

# %% [markdown]
# A large part of the world success rate is influenced by the success rate in the USA, which is not the case for the failure rate.

# %%
import geopandas as gpd
countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
iso_counts = countries_analysis.high_success_ratio.reset_index(name='high_success_ratio')
merged = countries.merge(iso_counts, left_on='iso_a3', right_on='country')
merged.plot(column='high_success_ratio', cmap='Greens', legend=True, figsize=(16,8))
plt.title('Startup Locations colored by High Success Rate',size=20)
plt.show()
# Out:
# /var/folders/_1/m8z38xzd6hv4d1hlr0776md00000gn/T/ipykernel_16452/1377090681.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %%
import geopandas as gpd
countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
iso_counts = countries_analysis.mid_success_ratio.reset_index(name='mid_success_ratio')
merged = countries.merge(iso_counts, left_on='iso_a3', right_on='country')
merged.plot(column='mid_success_ratio', cmap='YlOrBr', legend=True, figsize=(16,8))
plt.title('Startup Locations (> 50 startups) colored by Mid Success Rate',size=20)
plt.show()
# Out:
# /var/folders/_1/m8z38xzd6hv4d1hlr0776md00000gn/T/ipykernel_16452/4223244470.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %%
countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
iso_counts = countries_analysis.fail_ratio.reset_index(name='fail_ratio')
merged = countries.merge(iso_counts, left_on='iso_a3', right_on='country')
merged.plot(column='fail_ratio', cmap='Reds', legend=True, figsize=(16,8))
plt.title('Startup Locations (> 50 startups) colored by Fail Rate',size=20)
plt.show()
# Out:
# /var/folders/_1/m8z38xzd6hv4d1hlr0776md00000gn/T/ipykernel_16452/1924942424.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %% [markdown]
# We can see that the vast majority of countries with a high success rate are located between North America and Europe (except for Israel, China and Japan).
#
# On the other hand, we can clearly observe Russia as the country with the highest failure rate of all, being much higher than the rest. Followed by Peru, at a considerable distance.

# %%
df.head()
# Out:
#                      name country  year                          location  \
# 0                   #fame     IND  2015                            Mumbai
# 1                :Qounter     USA  2014         DE - Other, Delaware City
# 2  (THE) ONE of THEM,Inc.     FRA  2014                               NaN
# 3                 0-6.com     CHN  2007                           Beijing
# 4        004 Technologies     USA  2010  Springfield, Illinois, Champaign
#
#            main_category  funding_total_usd  funding_rounds first_funding_at  \
# 0                  Media         10000000.0               1       2015-01-05
# 1  Application Platforms           700000.0               2       2014-03-01
# 2                   Apps          3406878.0               1       2014-01-30
# 3            Curated Web          2000000.0               1       2008-03-19
# 4               Software          2000000.0               1       2014-07-24
#
#   last_funding_at     status status_class  fail  high  mid
# 0      2015-01-05  operating          mid     0     0    1
# 1      2014-10-14  operating          mid     0     0    1
# 2      2014-01-30  operating          mid     0     0    1
# 3      2008-03-19  operating          mid     0     0    1
# 4      2014-07-24  operating          mid     0     0    1

# %% [markdown]
# # MORE PRE PROCESSING

# %% [markdown]
# # Convert the dates to datetime format

# %%
# Formatting founded_at, first_funding_at, last_funding_at to datetime. If there are errors, convert it to NA
#df['founded_at'] = pd.to_datetime(df['founded_at'], format='%Y-%m-%d', errors='coerce')
df['first_funding_at'] = pd.to_datetime(df['first_funding_at'], format='%Y-%m-%d', errors='coerce')
df['last_funding_at'] = pd.to_datetime(df['last_funding_at'], format='%Y-%m-%d', errors='coerce')

# %%
# Create a new feature representing the duration between the first and last funding
df['funding_duration'] = (df['last_funding_at'] - df['first_funding_at']).dt.days

df.head()
# Out:
#                      name country  year                          location  \
# 0                   #fame     IND  2015                            Mumbai
# 1                :Qounter     USA  2014         DE - Other, Delaware City
# 2  (THE) ONE of THEM,Inc.     FRA  2014                               NaN
# 3                 0-6.com     CHN  2007                           Beijing
# 4        004 Technologies     USA  2010  Springfield, Illinois, Champaign
#
#            main_category  funding_total_usd  funding_rounds first_funding_at  \
# 0                  Media         10000000.0               1       2015-01-05
# 1  Application Platforms           700000.0               2       2014-03-01
# 2                   Apps          3406878.0               1       2014-01-30
# 3            Curated Web          2000000.0               1       2008-03-19
# 4               Software          2000000.0               1       2014-07-24
#
#   last_funding_at     status status_class  fail  high  mid  funding_duration
# 0      2015-01-05  operating          mid     0     0    1               0.0
# 1      2014-10-14  operating          mid     0     0    1             227.0
# 2      2014-01-30  operating          mid     0     0    1               0.0
# 3      2008-03-19  operating          mid     0     0    1               0.0
# 4      2014-07-24  operating          mid     0     0    1               0.0

# %%
df.isna().sum()
# Out:
# name                    1
# country                 0
# year                    0
# location             7927
# main_category           0
# funding_total_usd       0
# funding_rounds          0
# first_funding_at       26
# last_funding_at         0
# status                  0
# status_class            0
# fail                    0
# high                    0
# mid                     0
# funding_duration       26
# dtype: int64

# %% [markdown]
# # VIEWING THE EMPTY CELLS

# %%
# View rows with at least one NaN value
df_with_nan = df[df.isnull().any(axis=1)]

df_with_nan.tail(10)
# Out:
#                                              name country  year location  \
# 66264                                       Zubka     GBR  2006      NaN
# 66270                                       ZUGGI     USA  2010      NaN
# 66292                                   zumodrive     USA  2007      NaN
# 66298                                   Zuoyebang     USA  2015      NaN
# 66306                                        Zurn     CHN  2013      NaN
# 66317                                     ZUUMTEL     GBR  2014      NaN
# 66325             Zwayo "On-Demand Valet Parking"     CHN  2014      NaN
# 66333                                       Zyfin     USA  2011      NaN
# 66365                                       ÁERON     USA  2011      NaN
# 66367  İnovatiff Reklam ve Tanıtım Hizmetleri Tic     GBR  2013      NaN
#
#          main_category  funding_total_usd  funding_rounds first_funding_at  \
# 66264       Consulting        3919186.377               1       2007-02-09
# 66270           Search          40000.000               1       2011-06-20
# 66292  Cloud Computing        2000000.000               1       2007-09-01
# 66298            Other        2000000.000               1       2015-09-03
# 66306     Social Media        2000000.000               1       2013-12-01
# 66317       Automotive         300000.000               2       2013-04-01
# 66325             Apps          60000.000               1       2014-09-01
# 66333          Finance        2000000.000               1       2011-11-01
# 66365            Other        2000000.000               1       2014-08-01
# 66367   Consumer Goods          14851.000               1       2013-10-01
#
#       last_funding_at     status status_class  fail  high  mid  \
# 66264      2007-02-09     closed         fail     1     0    0
# 66270      2011-06-20  operating          mid     0     0    1
# 66292      2007-09-01  operating          mid     0     0    1
# 66298      2015-09-03  operating          mid     0     0    1
# 66306      2013-12-01  operating          mid     0     0    1
# 66317      2014-09-16     closed         fail     1     0    0
# 66325      2014-09-01  operating          mid     0     0    1
# 66333      2011-11-01  operating          mid     0     0    1
# 66365      2014-08-01  operating          mid     0     0    1
# 66367      2013-10-01  operating          mid     0     0    1
#
#        funding_duration
# 66264               0.0
# 66270               0.0
# 66292               0.0
# 66298               0.0
# 66306               0.0
# 66317             533.0
# 66325               0.0
# 66333               0.0
# 66365               0.0
# 66367               0.0

# %% [markdown]
# # HANDLING THE MISSING DATA IN LOCATION

# %%
# Define your constants for each country
constants = {
    'USA': 'New York City, New York',
    'GBR': 'London',
    'FRA': 'Paris',
    'IND': 'Mumbai',
    'CHN': 'Beijing',
    'ESP': 'Madrid',
    'HKG': 'Hong Kong',
    'ISR': 'Tel Aviv',
    'CAN': 'Toronto',
    'DEU': 'Berlin',
    'AUS': 'Sydney',
    'NLD': 'Amsterdam',
    'RUS': 'Moscow',
    'SGP': 'Singapore',
    'BRA': 'Porto Alegre',
    'JPN': 'Tokyo',
    'NOR': 'Oslo',
    'ITA': 'Turin',
    'SWE': 'Stockholm',
    'KOR': 'Seoul',
    'IRL':'Dublin',
    'CHL': 'Santiago',
    'BEL': 'Brussels, Ghent',
    'TWN': 'Taiwan, Taipei',
    'NZL': 'Auckland',
    'CHE': 'Zurich'
    
    
}

default_value = 'Unknown Location'

# Apply the fillna function with a lambda that uses the country to determine the constant
df['location'] = df.apply(
    lambda row: constants.get(row['country'], default_value) if pd.isnull(row['location']) else row['location'],
    axis=1
)

# %%
df['location'] = df['location'].replace('Unknown Location', np.nan)

# %%
df.isna().sum()
# Out:
# name                   1
# country                0
# year                   0
# location             530
# main_category          0
# funding_total_usd      0
# funding_rounds         0
# first_funding_at      26
# last_funding_at        0
# status                 0
# status_class           0
# fail                   0
# high                   0
# mid                    0
# funding_duration      26
# dtype: int64

# %%
df.dropna(inplace= True)

# %%
df.isna().sum()
# Out:
# name                 0
# country              0
# year                 0
# location             0
# main_category        0
# funding_total_usd    0
# funding_rounds       0
# first_funding_at     0
# last_funding_at      0
# status               0
# status_class         0
# fail                 0
# high                 0
# mid                  0
# funding_duration     0
# dtype: int64

# %%
df['first_funding_at'].dt.year.unique() >= 2023
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
df['last_funding_at'].dt.year.unique() >= 2023
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True])

# %%
df['last_funding_at'].dt.year.unique()
# Out:
# array([2015, 2014, 2008, 2009, 2013, 2011, 2010, 2006, 2012, 2007, 2004,
#        2003, 2005, 2002, 2001, 2000, 1994, 1999, 1998, 1995, 1996, 1997,
#        1993, 1992, 1989, 1990, 1986, 2105, 2115])

# %%
df.sort_values('last_funding_at', ascending = False)
# Out:
#                              name country  year                   location  \
# 63921          Wigzo Technologies     FRA  2014                      Paris
# 46956                Rasyonel R&D     TUR  2013                      Izmir
# 36653             Modern Movement     USA  2014                    Madison
# 25637                Hitsbook Inc     ESP  2011                     Madrid
# 30484               Keypair, Inc.     KOR  2012                   Seongnam
# ...                           ...     ...   ...                        ...
# 22374                   GECAD NET     ROM  1999                  Bucharest
# 28395                    Interhyp     DEU  1999                     Munich
# 46870  RampRate Sourcing Advisors     USA  2000  Los Angeles, Santa Monica
# 26838                        iGov     USA  1996   Washington, D.C., Reston
# 37921                     myTwins     ISR  2011                   Tel Aviv
#
#                         main_category  funding_total_usd  funding_rounds  \
# 63921                     Advertising           600000.0               2
# 46956  Embedded Hardware and Software           220000.0               3
# 36653                         Android            85000.0               2
# 25637          Entertainment Industry          1410000.0               3
# 30484                         FinTech          5000000.0               1
# ...                               ...                ...             ...
# 22374                             CAD             1000.0               1
# 28395                         Banking          2000000.0               1
# 46870                      Consulting          1000000.0               1
# 26838          Information Technology          2000000.0               1
# 37921                           Other          2000000.0               1
#
#       first_funding_at last_funding_at     status status_class  fail  high  \
# 63921       2014-08-18      2115-12-01  operating          mid     0     0
# 46956       2013-04-05      2105-05-01     closed         fail     1     0
# 36653       2014-07-18      2015-12-12  operating          mid     0     0
# 25637       2014-01-07      2015-12-07  operating          mid     0     0
# 30484       2015-12-05      2015-12-05  operating          mid     0     0
# ...                ...             ...        ...          ...   ...   ...
# 22374       1992-01-01      1992-01-01  operating          mid     0     0
# 28395       1990-09-01      1990-09-01  operating          mid     0     0
# 46870       1990-01-17      1990-01-17  operating          mid     0     0
# 26838       1989-10-30      1989-10-30  operating          mid     0     0
# 37921       1986-01-01      1986-01-01  operating          mid     0     0
#
#        mid  funding_duration
# 63921    1           36994.0
# 46956    0           33628.0
# 36653    1             512.0
# 25637    1             699.0
# 30484    1               0.0
# ...    ...               ...
# 22374    1               0.0
# 28395    1               0.0
# 46870    1               0.0
# 26838    1               0.0
# 37921    1               0.0
#
# [64300 rows x 15 columns]

# %%
df['last_funding_at'] = df['last_funding_at'].replace('21050501', '20150501')

# %%
df['last_funding_at'] = df['last_funding_at'].replace('21150501', '20150501')

# %% [markdown]
# # GETTING THE COMPANIES AGE

# %%
df['company_age'] = 2023 - df['year']
df.head()
# Out:
#                      name country  year                          location  \
# 0                   #fame     IND  2015                            Mumbai
# 1                :Qounter     USA  2014         DE - Other, Delaware City
# 2  (THE) ONE of THEM,Inc.     FRA  2014                             Paris
# 3                 0-6.com     CHN  2007                           Beijing
# 4        004 Technologies     USA  2010  Springfield, Illinois, Champaign
#
#            main_category  funding_total_usd  funding_rounds first_funding_at  \
# 0                  Media         10000000.0               1       2015-01-05
# 1  Application Platforms           700000.0               2       2014-03-01
# 2                   Apps          3406878.0               1       2014-01-30
# 3            Curated Web          2000000.0               1       2008-03-19
# 4               Software          2000000.0               1       2014-07-24
#
#   last_funding_at     status status_class  fail  high  mid  funding_duration  \
# 0      2015-01-05  operating          mid     0     0    1               0.0
# 1      2014-10-14  operating          mid     0     0    1             227.0
# 2      2014-01-30  operating          mid     0     0    1               0.0
# 3      2008-03-19  operating          mid     0     0    1               0.0
# 4      2014-07-24  operating          mid     0     0    1               0.0
#
#    company_age
# 0            8
# 1            9
# 2            9
# 3           16
# 4           13

# %% [markdown]
# # Average Funding per round

# %%
df['average_funding_per_round'] = df['funding_total_usd'] / df['funding_rounds']
df.head()
# Out:
#                      name country  year                          location  \
# 0                   #fame     IND  2015                            Mumbai
# 1                :Qounter     USA  2014         DE - Other, Delaware City
# 2  (THE) ONE of THEM,Inc.     FRA  2014                             Paris
# 3                 0-6.com     CHN  2007                           Beijing
# 4        004 Technologies     USA  2010  Springfield, Illinois, Champaign
#
#            main_category  funding_total_usd  funding_rounds first_funding_at  \
# 0                  Media         10000000.0               1       2015-01-05
# 1  Application Platforms           700000.0               2       2014-03-01
# 2                   Apps          3406878.0               1       2014-01-30
# 3            Curated Web          2000000.0               1       2008-03-19
# 4               Software          2000000.0               1       2014-07-24
#
#   last_funding_at     status status_class  fail  high  mid  funding_duration  \
# 0      2015-01-05  operating          mid     0     0    1               0.0
# 1      2014-10-14  operating          mid     0     0    1             227.0
# 2      2014-01-30  operating          mid     0     0    1               0.0
# 3      2008-03-19  operating          mid     0     0    1               0.0
# 4      2014-07-24  operating          mid     0     0    1               0.0
#
#    company_age  average_funding_per_round
# 0            8                 10000000.0
# 1            9                   350000.0
# 2            9                  3406878.0
# 3           16                  2000000.0
# 4           13                  2000000.0

# %% [markdown]
# # REDUCING THE COUNTRY CODE COLUMN

# %%
def shorten_categories(categories, cutoff):
    categorical_map = {}
    for i in range(len(categories)):
        if categories.values[i] >= cutoff:
            categorical_map[categories.index[i]] = categories.index[i]
        else:
            categorical_map[categories.index[i]] = 'Other'
    return categorical_map

# %%
country_map = shorten_categories(df.country.value_counts(), 5)
df['country'] = df['country'].map(country_map)
df.country.value_counts()
# Out:
# USA    40837
# GBR     4047
# CAN     2089
# IND     1754
# CHN     1710
#        ...
# TAN        7
# BMU        7
# BLR        6
# TTO        5
# BHR        5
# Name: country, Length: 83, dtype: int64

# %%
# let's list all categorical features
categorical_columns= [  
        'country'
       ]

# let's get the categories and their count for each feature
for col in categorical_columns:
  print(f"Categories and number of occurrences for '{col}'")
  pretty_print_df(df[col].value_counts())
  print()
# Out:
# Categories and number of occurrences for 'country'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>USA</th>
#       <td>40837</td>
#     </tr>
#     <tr>
#       <th>GBR</th>
#       <td>4047</td>
#     </tr>
#     <tr>
#       <th>CAN</th>
#       <td>2089</td>
#     </tr>
#     <tr>
#       <th>IND</th>
#       <td>1754</td>
#     </tr>
#     <tr>
#       <th>CHN</th>
#       <td>1710</td>
#     </tr>
#     <tr>
#       <th>FRA</th>
#       <td>1266</td>
#     </tr>
#     <tr>
#       <th>DEU</th>
#       <td>1195</td>
#     </tr>
#     <tr>
#       <th>ISR</th>
#       <td>1056</td>
#     </tr>
#     <tr>
#       <th>ESP</th>
#       <td>811</td>
#     </tr>
#     <tr>
#       <th>AUS</th>
#       <td>564</td>
#     </tr>
#     <tr>
#       <th>NLD</th>
#       <td>552</td>
#     </tr>
#     <tr>
#       <th>SGP</th>
#       <td>510</td>
#     </tr>
#     <tr>
#       <th>RUS</th>
#       <td>500</td>
#     </tr>
#     <tr>
#       <th>SWE</th>
#       <td>499</td>
#     </tr>
#     <tr>
#       <th>IRL</th>
#       <td>481</td>
#     </tr>
#     <tr>
#       <th>BRA</th>
#       <td>479</td>
#     </tr>
#     <tr>
#       <th>JPN</th>
#       <td>442</td>
#     </tr>
#     <tr>
#       <th>ITA</th>
#       <td>428</td>
#     </tr>
#     <tr>
#       <th>KOR</th>
#       <td>400</td>
#     </tr>
#     <tr>
#       <th>CHE</th>
#       <td>380</td>
#     </tr>
#     <tr>
#       <th>CHL</th>
#       <td>376</td>
#     </tr>
#     <tr>
#       <th>DNK</th>
#       <td>293</td>
#     </tr>
#     <tr>
#       <th>FIN</th>
#       <td>277</td>
#     </tr>
#     <tr>
#       <th>HKG</th>
#       <td>232</td>
#     </tr>
#     <tr>
#       <th>BEL</th>
#       <td>229</td>
#     </tr>
#     <tr>
#       <th>ARG</th>
#       <td>184</td>
#     </tr>
#     <tr>
#       <th>TUR</th>
#       <td>173</td>
#     </tr>
#     <tr>
#       <th>NOR</th>
#       <td>148</td>
#     </tr>
#     <tr>
#       <th>POL</th>
#       <td>147</td>
#     </tr>
#     <tr>
#       <th>MEX</th>
#       <td>134</td>
#     </tr>
#     <tr>
#       <th>AUT</th>
#       <td>131</td>
#     </tr>
#     <tr>
#       <th>NZL</th>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>PRT</th>
#       <td>108</td>
#     </tr>
#     <tr>
#       <th>IDN</th>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>BGR</th>
#       <td>93</td>
#     </tr>
#     <tr>
#       <th>ARE</th>
#       <td>91</td>
#     </tr>
#     <tr>
#       <th>ZAF</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>MYS</th>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>EST</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>CZE</th>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>TWN</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>PHL</th>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>UKR</th>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>COL</th>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>NGA</th>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>THA</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>HUN</th>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>LVA</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>LTU</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>PER</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>GRC</th>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>VNM</th>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>ROM</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>KEN</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>EGY</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>LUX</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>JOR</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>PAK</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>SVK</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>ISL</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>SVN</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>LBN</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>CYP</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>URY</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>UGA</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>GHA</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>SRB</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>BGD</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>CRI</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>VEN</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>CYM</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>PAN</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>SAU</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>KHM</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>HRV</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>MUS</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>ECU</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>TAN</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>BMU</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>BLR</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>TTO</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>BHR</th>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # CREATING A COUNTRY NAME COLUMN

# %%
df = df[df['country'] != 'Other']

# %%
country_dict = {
    'USA': 'United States',
    'GBR': 'United Kingdom',
    'CAN': 'Canada',
    'IND': 'India',
    'CHN': 'China',
    'FRA': 'France',
    'DEU': 'Germany',
    'ISR': 'Israel',
    'ESP': 'Spain',
    'AUS': 'Australia',
    'NLD': 'Netherlands',
    'RUS': 'Russia',
    'SGP': 'Singapore',
    'SWE': 'Sweden',
    'IRL': 'Ireland',
    'BRA': 'Brazil',
    'JPN': 'Japan',
    'ITA': 'Italy',
    'KOR': 'South Korea',
    'CHE': 'Switzerland',
    'CHL': 'Chile',
    'DNK': 'Denmark',
    'FIN': 'Finland',
    'BEL': 'Belgium',
    'HKG': 'Hong Kong',
    'ARG': 'Argentina',
    'TUR': 'Turkey',
    'POL': 'Poland',
    'MEX': 'Mexico',
    'NOR': 'Norway',
    'AUT': 'Austria',
    'PRT': 'Portugal',
    'IDN': 'Indonesia',
    'BGR': 'Bulgaria',
    'NZL': 'New Zealand',
    'ZAF': 'South Africa',
    'ARE': 'United Arab Emirates',
    'MYS': 'Malaysia',
    'EST': 'Estonia',
    'CZE': 'Czech Republic',
    'PHL': 'Philippines',
    'UKR': 'Ukraine',
    'THA': 'Thailand',
    'NGA': 'Nigeria',
    'TWN': 'Taiwan',
    'COL': 'Colombia',
    'HUN': 'Hungary',
    'PER': 'Peru',
    'LVA': 'Latvia',
    'VNM': 'Vietnam',
    'LTU': 'Lithuania',
    'GRC': 'Greece',
    'KEN': 'Kenya',
    'EGY': 'Egypt',
    'ROM': 'Romania',
    'SVK': 'Slovakia',
    'JOR': 'Jordan',
    'LUX': 'Luxembourg',
    'PAK': 'Pakistan',
    'LBN': 'Lebanon',
    'ISL': 'Iceland',
    'SVN': 'Slovenia',
    'CYP': 'Cyprus',
    'UGA': 'Uganda',
    'GHA': 'Ghana',
    'CYM': 'Cayman Islands',
    'SRB': 'Serbia',
    'URY': 'Uruguay',
    'VEN': 'Venezuela',
    'KHM': 'Cambodia',
    'BGD': 'Bangladesh',
    'CRI': 'Costa Rica',
    'PAN': 'Panama',
    'SAU': 'Saudi Arabia',
    'TAN': 'Tanzania',
    'MLT': 'Malta',
    'HRV': 'Croatia',
    'MUS': 'Mauritius',
    'BLR': 'Belarus',
    'GTM': 'Guatemala',
    'ECU': 'Ecuador',
    'BMU': 'Bermuda',
    'NPL': 'Nepal',
    'TTO': 'Trinidad and Tobago',
    'BHR': 'Bahrain',
    'MKD': 'North Macedonia',
    'LIE': 'Liechtenstein',
}


# Now, create a new column 'country_fullname' by mapping the 'country' column using the dictionary
df['country_name'] = df['country'].map(country_dict)

# If there are any missing values after this operation (if there were any country abbreviations
# not included in your dictionary), you can choose to drop these rows like this:
df = df.dropna(subset=['country_name'])

# %%
df.head()
# Out:
#                      name country  year                          location  \
# 0                   #fame     IND  2015                            Mumbai
# 1                :Qounter     USA  2014         DE - Other, Delaware City
# 2  (THE) ONE of THEM,Inc.     FRA  2014                             Paris
# 3                 0-6.com     CHN  2007                           Beijing
# 4        004 Technologies     USA  2010  Springfield, Illinois, Champaign
#
#            main_category  funding_total_usd  funding_rounds first_funding_at  \
# 0                  Media         10000000.0               1       2015-01-05
# 1  Application Platforms           700000.0               2       2014-03-01
# 2                   Apps          3406878.0               1       2014-01-30
# 3            Curated Web          2000000.0               1       2008-03-19
# 4               Software          2000000.0               1       2014-07-24
#
#   last_funding_at     status status_class  fail  high  mid  funding_duration  \
# 0      2015-01-05  operating          mid     0     0    1               0.0
# 1      2014-10-14  operating          mid     0     0    1             227.0
# 2      2014-01-30  operating          mid     0     0    1               0.0
# 3      2008-03-19  operating          mid     0     0    1               0.0
# 4      2014-07-24  operating          mid     0     0    1               0.0
#
#    company_age  average_funding_per_round   country_name
# 0            8                 10000000.0          India
# 1            9                   350000.0  United States
# 2            9                  3406878.0         France
# 3           16                  2000000.0          China
# 4           13                  2000000.0  United States

# %%
counts = df['main_category'].value_counts()

# Now let's create a list of all categories that occur less than 5 times
to_remove = counts[counts < 5].index

# Drop these rows from the DataFrame
df = df[~df['main_category'].isin(to_remove)]

# Now, let's remove the 'others' row
df = df[df['main_category'] != 'others']

# %%
# let's list all categorical features
categorical_columns= [  
        'main_category'
       ]

# let's get the categories and their count for each feature
for col in categorical_columns:
  print(f"Categories and number of occurrences for '{col}'")
  pretty_print_df(df[col].value_counts())
  print()
# Out:
# Categories and number of occurrences for 'main_category'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>main_category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Biotechnology</th>
#       <td>4322</td>
#     </tr>
#     <tr>
#       <th>Software</th>
#       <td>3987</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>2905</td>
#     </tr>
#     <tr>
#       <th>E-Commerce</th>
#       <td>2689</td>
#     </tr>
#     <tr>
#       <th>Advertising</th>
#       <td>2364</td>
#     </tr>
#     <tr>
#       <th>Curated Web</th>
#       <td>2161</td>
#     </tr>
#     <tr>
#       <th>Mobile</th>
#       <td>1736</td>
#     </tr>
#     <tr>
#       <th>Analytics</th>
#       <td>1619</td>
#     </tr>
#     <tr>
#       <th>Apps</th>
#       <td>1482</td>
#     </tr>
#     <tr>
#       <th>Health Care</th>
#       <td>1390</td>
#     </tr>
#     <tr>
#       <th>Clean Technology</th>
#       <td>1362</td>
#     </tr>
#     <tr>
#       <th>Enterprise Software</th>
#       <td>1335</td>
#     </tr>
#     <tr>
#       <th>Games</th>
#       <td>1251</td>
#     </tr>
#     <tr>
#       <th>Health and Wellness</th>
#       <td>1165</td>
#     </tr>
#     <tr>
#       <th>Finance</th>
#       <td>1087</td>
#     </tr>
#     <tr>
#       <th>Hardware + Software</th>
#       <td>1052</td>
#     </tr>
#     <tr>
#       <th>Education</th>
#       <td>977</td>
#     </tr>
#     <tr>
#       <th>Manufacturing</th>
#       <td>825</td>
#     </tr>
#     <tr>
#       <th>Consulting</th>
#       <td>674</td>
#     </tr>
#     <tr>
#       <th>Internet</th>
#       <td>622</td>
#     </tr>
#     <tr>
#       <th>Cloud Computing</th>
#       <td>605</td>
#     </tr>
#     <tr>
#       <th>Entertainment</th>
#       <td>563</td>
#     </tr>
#     <tr>
#       <th>Android</th>
#       <td>538</td>
#     </tr>
#     <tr>
#       <th>Semiconductors</th>
#       <td>499</td>
#     </tr>
#     <tr>
#       <th>Hospitality</th>
#       <td>485</td>
#     </tr>
#     <tr>
#       <th>Social Media</th>
#       <td>485</td>
#     </tr>
#     <tr>
#       <th>Real Estate</th>
#       <td>455</td>
#     </tr>
#     <tr>
#       <th>Fashion</th>
#       <td>453</td>
#     </tr>
#     <tr>
#       <th>Automotive</th>
#       <td>447</td>
#     </tr>
#     <tr>
#       <th>Security</th>
#       <td>443</td>
#     </tr>
#     <tr>
#       <th>Big Data</th>
#       <td>409</td>
#     </tr>
#     <tr>
#       <th>Business Services</th>
#       <td>389</td>
#     </tr>
#     <tr>
#       <th>Information Technology</th>
#       <td>359</td>
#     </tr>
#     <tr>
#       <th>Design</th>
#       <td>358</td>
#     </tr>
#     <tr>
#       <th>Web Hosting</th>
#       <td>345</td>
#     </tr>
#     <tr>
#       <th>Consumer Electronics</th>
#       <td>317</td>
#     </tr>
#     <tr>
#       <th>B2B</th>
#       <td>317</td>
#     </tr>
#     <tr>
#       <th>Medical</th>
#       <td>312</td>
#     </tr>
#     <tr>
#       <th>Consumer Goods</th>
#       <td>302</td>
#     </tr>
#     <tr>
#       <th>Financial Services</th>
#       <td>301</td>
#     </tr>
#     <tr>
#       <th>EdTech</th>
#       <td>297</td>
#     </tr>
#     <tr>
#       <th>Collaboration</th>
#       <td>294</td>
#     </tr>
#     <tr>
#       <th>Technology</th>
#       <td>288</td>
#     </tr>
#     <tr>
#       <th>Content</th>
#       <td>271</td>
#     </tr>
#     <tr>
#       <th>Messaging</th>
#       <td>266</td>
#     </tr>
#     <tr>
#       <th>Music</th>
#       <td>252</td>
#     </tr>
#     <tr>
#       <th>News</th>
#       <td>246</td>
#     </tr>
#     <tr>
#       <th>Digital Media</th>
#       <td>243</td>
#     </tr>
#     <tr>
#       <th>Travel</th>
#       <td>240</td>
#     </tr>
#     <tr>
#       <th>Big Data Analytics</th>
#       <td>237</td>
#     </tr>
#     <tr>
#       <th>Application Platforms</th>
#       <td>224</td>
#     </tr>
#     <tr>
#       <th>Media</th>
#       <td>222</td>
#     </tr>
#     <tr>
#       <th>Networking</th>
#       <td>221</td>
#     </tr>
#     <tr>
#       <th>Fitness</th>
#       <td>207</td>
#     </tr>
#     <tr>
#       <th>Brand Marketing</th>
#       <td>204</td>
#     </tr>
#     <tr>
#       <th>Computers</th>
#       <td>199</td>
#     </tr>
#     <tr>
#       <th>Energy</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>Sports</th>
#       <td>189</td>
#     </tr>
#     <tr>
#       <th>Services</th>
#       <td>189</td>
#     </tr>
#     <tr>
#       <th>Photography</th>
#       <td>187</td>
#     </tr>
#     <tr>
#       <th>Search</th>
#       <td>182</td>
#     </tr>
#     <tr>
#       <th>Public Relations</th>
#       <td>177</td>
#     </tr>
#     <tr>
#       <th>Medical Devices</th>
#       <td>173</td>
#     </tr>
#     <tr>
#       <th>Customer Service</th>
#       <td>171</td>
#     </tr>
#     <tr>
#       <th>Marketplaces</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>Beauty</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>Crowdfunding</th>
#       <td>168</td>
#     </tr>
#     <tr>
#       <th>Consumers</th>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>Art</th>
#       <td>161</td>
#     </tr>
#     <tr>
#       <th>Communities</th>
#       <td>159</td>
#     </tr>
#     <tr>
#       <th>Pharmaceuticals</th>
#       <td>158</td>
#     </tr>
#     <tr>
#       <th>Crowdsourcing</th>
#       <td>157</td>
#     </tr>
#     <tr>
#       <th>Artificial Intelligence</th>
#       <td>154</td>
#     </tr>
#     <tr>
#       <th>3D</th>
#       <td>147</td>
#     </tr>
#     <tr>
#       <th>Enterprises</th>
#       <td>147</td>
#     </tr>
#     <tr>
#       <th>Banking</th>
#       <td>147</td>
#     </tr>
#     <tr>
#       <th>Electronics</th>
#       <td>142</td>
#     </tr>
#     <tr>
#       <th>Agriculture</th>
#       <td>142</td>
#     </tr>
#     <tr>
#       <th>CRM</th>
#       <td>141</td>
#     </tr>
#     <tr>
#       <th>Transportation</th>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>Bitcoin</th>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>Events</th>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>Audio</th>
#       <td>138</td>
#     </tr>
#     <tr>
#       <th>Delivery</th>
#       <td>133</td>
#     </tr>
#     <tr>
#       <th>Accounting</th>
#       <td>129</td>
#     </tr>
#     <tr>
#       <th>Human Resources</th>
#       <td>127</td>
#     </tr>
#     <tr>
#       <th>Blogging Platforms</th>
#       <td>127</td>
#     </tr>
#     <tr>
#       <th>Food Processing</th>
#       <td>126</td>
#     </tr>
#     <tr>
#       <th>Aerospace</th>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>Career Management</th>
#       <td>117</td>
#     </tr>
#     <tr>
#       <th>Cloud Data Services</th>
#       <td>115</td>
#     </tr>
#     <tr>
#       <th>Nanotechnology</th>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>All Students</th>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>SaaS</th>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>Bio-Pharm</th>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>Public Transportation</th>
#       <td>107</td>
#     </tr>
#     <tr>
#       <th>Ad Targeting</th>
#       <td>106</td>
#     </tr>
#     <tr>
#       <th>Broadcasting</th>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>Chat</th>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>Hardware</th>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>Databases</th>
#       <td>98</td>
#     </tr>
#     <tr>
#       <th>Telecommunications</th>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>Legal</th>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>Facebook Applications</th>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>Nonprofits</th>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>Clean Energy</th>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>Colleges</th>
#       <td>94</td>
#     </tr>
#     <tr>
#       <th>Information Services</th>
#       <td>93</td>
#     </tr>
#     <tr>
#       <th>3D Printing</th>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>Coupons</th>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>Location Based Services</th>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>Collaborative Consumption</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>Cyber Security</th>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>Business Intelligence</th>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>Internet of Things</th>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>Game</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>Retail</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>Construction</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>Email</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>Advertising Platforms</th>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th

# %%
df.head()
# Out:
#                      name country  year                          location  \
# 0                   #fame     IND  2015                            Mumbai
# 1                :Qounter     USA  2014         DE - Other, Delaware City
# 2  (THE) ONE of THEM,Inc.     FRA  2014                             Paris
# 3                 0-6.com     CHN  2007                           Beijing
# 4        004 Technologies     USA  2010  Springfield, Illinois, Champaign
#
#            main_category  funding_total_usd  funding_rounds first_funding_at  \
# 0                  Media         10000000.0               1       2015-01-05
# 1  Application Platforms           700000.0               2       2014-03-01
# 2                   Apps          3406878.0               1       2014-01-30
# 3            Curated Web          2000000.0               1       2008-03-19
# 4               Software          2000000.0               1       2014-07-24
#
#   last_funding_at     status status_class  fail  high  mid  funding_duration  \
# 0      2015-01-05  operating          mid     0     0    1               0.0
# 1      2014-10-14  operating          mid     0     0    1             227.0
# 2      2014-01-30  operating          mid     0     0    1               0.0
# 3      2008-03-19  operating          mid     0     0    1               0.0
# 4      2014-07-24  operating          mid     0     0    1               0.0
#
#    company_age  average_funding_per_round   country_name
# 0            8                 10000000.0          India
# 1            9                   350000.0  United States
# 2            9                  3406878.0         France
# 3           16                  2000000.0          China
# 4           13                  2000000.0  United States

# %%
df.tail()
# Out:
#                                              name country  year  \
# 66363               ZZNode Science and Technology     CHN  2012
# 66364                       Zzzzapp Wireless ltd.     HRV  2012
# 66365                                       ÁERON     USA  2011
# 66366                                       Ôasys     USA  2014
# 66367  İnovatiff Reklam ve Tanıtım Hizmetleri Tic     GBR  2013
#
#                          location         main_category  funding_total_usd  \
# 66363                     Beijing   Enterprise Software          1587301.0
# 66364                       Split           Advertising           114304.0
# 66365     New York City, New York                 Other          2000000.0
# 66366  SF Bay Area, San Francisco  Consumer Electronics            18192.0
# 66367                      London        Consumer Goods            14851.0
#
#        funding_rounds first_funding_at last_funding_at     status  \
# 66363               1       2012-04-01      2012-04-01  operating
# 66364               4       2011-11-01      2014-03-01  operating
# 66365               1       2014-08-01      2014-08-01  operating
# 66366               1       2015-01-01      2015-01-01  operating
# 66367               1       2013-10-01      2013-10-01  operating
#
#       status_class  fail  high  mid  funding_duration  company_age  \
# 66363          mid     0     0    1               0.0           11
# 66364          mid     0     0    1             851.0           11
# 66365          mid     0     0    1               0.0           12
# 66366          mid     0     0    1               0.0            9
# 66367          mid     0     0    1               0.0           10
#
#        average_funding_per_round    country_name
# 66363                  1587301.0           China
# 66364                    28576.0         Croatia
# 66365                  2000000.0   United States
# 66366                    18192.0   United States
# 66367                    14851.0  United Kingdom

# %%
df.to_csv('startup.csv', index=False)

# %% [markdown]
# # CHECKING FOR CLASS DISTRIBUTION

# %%
print("Class distribution:\n", df['status_class'].value_counts())
# Out:
# Class distribution:
#  mid     51165
# high     6627
# fail     5967
# Name: status_class, dtype: int64

# %%
# Visualize class distribution
sns.countplot(x='status_class', data=df)
plt.show()

# %% [markdown]
# # ENCODING THE CATEGORICAL DATA

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# Create a label (category) encoder object
le_country_name = LabelEncoder()

le_country_name.fit(df['country_name'])

# View the labels (if you wish)
list(le_country_name.classes_)

# Apply the fitted encoder to the pandas column
df['Country'] = le_country_name.transform(df['country_name'])

# %%
# Create a label (category) encoder object
le_main_category = LabelEncoder()

le_main_category.fit(df['main_category'])

# View the labels (if you wish)
list(le_main_category.classes_)

# Apply the fitted encoder to the pandas column
df['Category'] = le_main_category.transform(df['main_category'])

# %%
# Create a label (category) encoder object
le_status_class = LabelEncoder()

le_status_class.fit(df['status_class'])

# View the labels (if you wish)
list(le_status_class.classes_)

# Apply the fitted encoder to the pandas column
df['Status'] = le_status_class.transform(df['status_class'])

# %%
# Create a label (category) encoder object
le_location = LabelEncoder()

le_location.fit(df['location'])

# View the labels (if you wish)
list(le_location.classes_)

# Apply the fitted encoder to the pandas column
df['Location'] = le_location.transform(df['location'])

# %%
df.head()
# Out:
#                      name country  year                          location  \
# 0                   #fame     IND  2015                            Mumbai
# 1                :Qounter     USA  2014         DE - Other, Delaware City
# 2  (THE) ONE of THEM,Inc.     USA  2014           New York City, New York
# 3                 0-6.com     CHN  2007                           Beijing
# 4        004 Technologies     USA  2010  Springfield, Illinois, Champaign
#
#            main_category  funding_total_usd  funding_rounds first_funding_at  \
# 0                  Media         10000000.0               1       2015-01-05
# 1  Application Platforms           700000.0               2       2014-03-01
# 2                   Apps          3406878.0               1       2014-01-30
# 3            Curated Web          2000000.0               1       2008-03-19
# 4               Software          2000000.0               1       2014-07-24
#
#   last_funding_at     status  ... high  mid  funding_duration  company_age  \
# 0      2015-01-05  operating  ...    0    1               0.0            8
# 1      2014-10-14  operating  ...    0    1             227.0            9
# 2      2014-01-30  operating  ...    0    1               0.0            9
# 3      2008-03-19  operating  ...    0    1               0.0           16
# 4      2014-07-24  operating  ...    0    1               0.0           13
#
#    average_funding_per_round   country_name  Country Category  Status  \
# 0                 10000000.0          India       32      363       2
# 1                   350000.0  United States       78       28       2
# 2                  3406878.0  United States       78       29       2
# 3                  2000000.0          China       14      156       2
# 4                  2000000.0  United States       78      479       2
#
#    Location
# 0      3354
# 1      1147
# 2      3704
# 3       461
# 4      4833
#
# [5 rows x 22 columns]

# %% [markdown]
# # FEATURE EXTRACTION

# %% [markdown]
# # SEPARATING THE FEATURE AND TARGET VARIABLES

# %%
X = df[[ "funding_total_usd", "funding_rounds", "funding_duration", "company_age", 
                  "average_funding_per_round", "Country", "Category", "Location" ]]

y= df["status_class"]

# %% [markdown]
# # SCALE THE DATA

# %%
from sklearn.preprocessing import StandardScaler

# create an instance of StandardScaler
scaler = StandardScaler()

# fit the scaler to the training data and transform it
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.8, random_state=42)

# %% [markdown]
# # FIXING CLASS IMBALANCE

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %% [markdown]
# # VIEWING THE TARGET AFTER OVERSAMPLING

# %%
import matplotlib.pyplot as plt

# Get the class distribution of the resampled data
class_distribution = y_resampled.value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
class_distribution.plot(kind='bar', color=['green', 'purple'])
plt.title('Class Distribution after Resampling')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # CLASSIFICATION

# %% [markdown]
# # CREATING A FUNCTION TO EVALUATE THE MODEL PERFORMANCE

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

def evaluate_model_performance(model, X_test, y_test):
    y_pred = model.predict(X_test)

    # Calculating the performance metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    # Print performance metrics
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

    print("Classification Report:\n", classification_report(y_test, y_pred))

 

    # Create confusion matrix and display it as a heatmap
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

# %% [markdown]
# # TRIVAL BASELINE

# %%
from sklearn.dummy import DummyClassifier

baseline = DummyClassifier(strategy= "prior")

# Fit the baseline model on the resampled data
baseline.fit(X_resampled, y_resampled)

# Predict on the test data
pred = baseline.predict(X_test)

# Evaluate model performance
evaluate_model_performance(baseline, X_test, y_test)
# Out:
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.09339711417816814
# Precision: 0.008723020936809775
# Recall: 0.09339711417816814
# F1 Score: 0.015955814815491392
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.09      1.00      0.17      4764
#         high       0.00      0.00      0.00      5321
#          mid       0.00      0.00      0.00     40923
#
#     accuracy                           0.09     51008
#    macro avg       0.03      0.33      0.06     51008
# weighted avg       0.01      0.09      0.02     51008

# %% [markdown]
# # Binary classsification without grid sesarch

# %% [markdown]
# # RF NO GRID SEARCH

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier (random_state=42)
clf.fit(X_resampled, y_resampled)
print("Random Forest Results:")
rf_results = evaluate_model_performance(clf, X_test, y_test)
# Out:
# Random Forest Results:
# Accuracy: 0.7049286386449184
# Precision: 0.7353105546464338
# Recall: 0.7049286386449184
# F1 Score: 0.7183866187960006
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.19      0.22      0.20      4764
#         high       0.30      0.41      0.35      5321
#          mid       0.86      0.80      0.83     40923
#
#     accuracy                           0.70     51008
#    macro avg       0.45      0.48      0.46     51008
# weighted avg       0.74      0.70      0.72     51008

# %% [markdown]
# # DT NO GRID SEARCH

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier(random_state=42)
clf1.fit(X_resampled, y_resampled)
dt_results = evaluate_model_performance(clf1, X_test, y_test)
# Out:
# Accuracy: 0.651564460476788
# Precision: 0.7154091220165273
# Recall: 0.651564460476788
# F1 Score: 0.6789877857620606
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.16      0.25      0.20      4764
#         high       0.23      0.32      0.27      5321
#          mid       0.84      0.74      0.79     40923
#
#     accuracy                           0.65     51008
#    macro avg       0.41      0.44      0.42     51008
# weighted avg       0.72      0.65      0.68     51008

# %% [markdown]
# # CLASSIFICATION WITH GRID SEARCH

# %% [markdown]
# # RANDOM FOREST

# %%
import warnings
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
warnings.simplefilter("ignore")

# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],  # number of trees in the forest
    'max_depth': [None, 10, 20, 30],  # maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]  # minimum number of samples required to be at a leaf node
}

# Create a base model
rf = RandomForestClassifier(random_state=42)

# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, 
                          cv=3, n_jobs=-1, verbose=2, scoring='f1_macro')

# Fit the grid search to the data
grid_search.fit(X_resampled, y_resampled)

# Get the best parameters
best_params = grid_search.best_params_
print(f"Best parameters: {best_params}")
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Best parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
# Get the best model
best_rf = grid_search.best_estimator_

# Evaluate its performance
evaluate_model_performance(best_rf, X_test, y_test)
# Out:
# Accuracy: 0.7020709130844054
# Precision: 0.7360720909331802
# Recall: 0.7020709130844054
# F1 Score: 0.7170658296436172
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.20      0.25      0.23      1202
#    operating       0.85      0.79      0.82     10177
#      success       0.32      0.43      0.37      1369
#
#     accuracy                           0.70     12748
#    macro avg       0.46      0.49      0.47     12748
# weighted avg       0.74      0.70      0.72     12748

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
param_grid = {
    "criterion": ["gini", "entropy", "log_loss"],
    "max_features": ["auto","sqrt", "log2"], 
    "splitter":["best", "random"]
}

dt = DecisionTreeClassifier()

grid = GridSearchCV(estimator=rf, param_grid=param_grid, cv=10, scoring='accuracy', refit=True)
grid = grid.fit(X_resampled, y_resampled)

print('Best estimator:', grid.best_estimator_)
print('Best params:', grid.best_params_)
print('Best Score:', grid.best_score_)

# get feature importance of the best estimator
feature_importance = grid.best_estimator_.feature_importances_
print('Feature importance:', feature_importance)
# Out:
# Best estimator: DecisionTreeClassifier(criterion='entropy', max_features='log2',
#                        splitter='random')
# Best params: {'criterion': 'entropy', 'max_features': 'log2', 'splitter': 'random'}
# Best Score: 0.7672513246303134
# Feature importance: [0.07384201 0.14925732 0.17860134 0.22571235 0.06653312 0.12543313
#  0.05276844 0.12785229]

# %%
dt = grid.best_estimator_
print("Decision Tree Results:")
dt_results = evaluate_model_performance(dt, X_test, y_test)
# Out:
# Decision Tree Results:
# Accuracy: 0.6291967367430185
# Precision: 0.713626283329447
# Recall: 0.6291967367430185
# F1 Score: 0.6636701517832765
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.16      0.29      0.21      1202
#    operating       0.84      0.71      0.77     10177
#      success       0.24      0.35      0.28      1369
#
#     accuracy                           0.63     12748
#    macro avg       0.41      0.45      0.42     12748
# weighted avg       0.71      0.63      0.66     12748

# %% [markdown]
# # K-Nearest Neighbors

# %%
import warnings
warnings.simplefilter("ignore")
from sklearn.neighbors import KNeighborsClassifier

param_grid = {
    "n_neighbors": list(range(1, 31)),  
    "weights": ["uniform", "distance"],  
    "metric": ["euclidean", "manhattan", "minkowski"] 
}

knn = KNeighborsClassifier()

grid = GridSearchCV(estimator=knn, param_grid=param_grid, cv=10, scoring='accuracy', refit=True)
grid = grid.fit(X_resampled, y_resampled)

print('Best estimator:', grid.best_estimator_)
print('Best params:', grid.best_params_)
print('Best Score:', grid.best_score_)
# Out:
# Best estimator: KNeighborsClassifier(metric='manhattan', n_neighbors=2, weights='distance')
# Best params: {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'distance'}
# Best Score: 0.8635803729149444

# %%
# K-Nearest Neighbors
knn = grid.best_estimator_
knn.fit(X_resampled, y_resampled)
print("K-Nearest Neighbors Results:")
knn_results = evaluate_model_performance(knn, X_test, y_test)
# Out:
# K-Nearest Neighbors Results:
# Accuracy: 0.6630059617194854
# Precision: 0.7104076869337967
# Recall: 0.6630059617194854
# F1 Score: 0.6840139638373116
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.17      0.26      0.21      1202
#    operating       0.84      0.76      0.80     10177
#      success       0.24      0.30      0.27      1369
#
#     accuracy                           0.66     12748
#    macro avg       0.42      0.44      0.42     12748
# weighted avg       0.71      0.66      0.68     12748

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
import warnings
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

warnings.simplefilter("ignore")

param_grid = {
    'C': np.logspace(-4, 4, 20),  
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], 
    'max_iter': [20000],
    'class_weight': ['balanced']
}

lr = LogisticRegression()

grid = GridSearchCV(estimator=lr, param_grid=param_grid, cv=10, scoring='accuracy', refit=True)
grid = grid.fit(X_resampled, y_resampled)

print('Best estimator: {}\nWeights: {}, Intercept: {}\nBest params: {}'.format(
    grid.best_estimator_, grid.best_estimator_.coef_, grid.best_estimator_.intercept_, grid.best_params_))
# Out:
# Best estimator: LogisticRegression(C=0.0001, class_weight='balanced', max_iter=20000,
#                    solver='liblinear')
# Weights: [[ 0.00388048  0.03555696  0.08848289 -0.13660123 -0.18602866 -0.06534355
#   -0.20963485 -0.05357661]
#  [-0.08848049 -0.09781936 -0.02626581 -0.4374645   0.0016219  -0.05031765
#   -0.0010432  -0.05150646]
#  [ 0.06495651  0.03972993 -0.0745542   0.45036073  0.16561116  0.08837117
#    0.17669214  0.09242945]], Intercept: [-0.49531324 -0.43569202 -0.65025837]
# Best params: {'C': 0.0001, 'class_weight': 'balanced', 'max_iter': 20000, 'solver': 'liblinear'}

# %%
log_reg = grid.best_estimator_
log_reg.fit(X_resampled, y_resampled)
print("Logistic Regression Results:")
log_reg_results = evaluate_model_performance(log_reg, X_test, y_test)
# Out:
# Logistic Regression Results:
# Accuracy: 0.4964700345152181
# Precision: 0.7551578858570281
# Recall: 0.4964700345152181
# F1 Score: 0.5606816366024007
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.14      0.44      0.21      1202
#    operating       0.90      0.48      0.63     10177
#      success       0.25      0.64      0.36      1369
#
#     accuracy                           0.50     12748
#    macro avg       0.43      0.52      0.40     12748
# weighted avg       0.76      0.50      0.56     12748

# %% [markdown]
# # NEURAL NETWORK

# %%
pip install scikeras
# Out:
# Requirement already satisfied: scikeras in /Users/mac/anaconda3/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: grpcio<1.50.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from scikeras) (1.49.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from scikeras) (1.2.2)
# Requirement already satisfied: packaging>=0.21 in /Users/mac/anaconda3/lib/python3.10/site-packages (from scikeras) (22.0)
# Requirement already satisfied: six>=1.5.2 in /Users/mac/anaconda3/lib/python3.10/site-packages (from grpcio<1.50.0->scikeras) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->scikeras) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/mac/anaconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->scikeras) (1.10.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/mac/anaconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->scikeras) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->scikeras) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/mac/anaconda3/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: packaging in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (23.5.9)
# Requirement already satisfied: h5py>=2.9.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.49.1)
# Requirement already satisfied: jax>=0.3.15 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.4.10)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in /Users/mac/anaconda3/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (1.10.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.18.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: urllib3<2.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (1.26.14)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mac/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mac/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/mac/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/mac/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/mac/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scikeras.wrappers import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras import models
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.losses import binary_crossentropy
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
import tensorflow as tf
from tensorflow.keras import datasets, layers, models


def one_layer_model(num_of_input_features, hidden_layer_nodes=20):
    """ 
    We wrap the model into a function for better usability.
    We make some of the important hyper-parameters, like the learning rate, 
    as arguments to the function. This way we can test different values for these
    hyperparameters without having to change the hard-coded model itself.
    """
    # create a simple model with ONE hidden layer only
    model = models.Sequential()
    # we create a hidden layer with 20 nodes. 
    # Here we can directly give it the input shape. Otherwise we can also create a separate input layer
    model.add(layers.Dense(hidden_layer_nodes, input_dim=num_of_input_features, activation='relu'))
    model.add(layers.Dense(7, activation='softmax')) #is it clear why here we use "sigmoid" and use "softmax" for multi-class problems?
    return model


clf = KerasClassifier(
    model=one_layer_model,
    loss="sparse_categorical_crossentropy",
    model__hidden_layer_nodes=20,
    num_of_input_features= X_train.shape[1],
    epochs= 50,
    batch_size= 64,
    verbose= 0,
    validation_split= 0.2,
    optimizer = "adam",
    optimizer__learning_rate = 0.001,
)

params = {
    'optimizer__learning_rate': [0.01, 0.001],
    'model__hidden_layer_nodes': [20,30,40],
}

gs = GridSearchCV(clf, params, scoring='balanced_accuracy', verbose=True)

gs.fit(X_resampled, y_resampled)


print(gs.best_score_, gs.best_params_)
# Out:
# 2023-07-15 02:40:01.382684: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# 0.5378127569347532 {'model__hidden_layer_nodes': 40, 'optimizer__learning_rate': 0.001}

# %%
# Check performance on test data
test_probabilities = gs.best_estimator_.predict(X_test)
# let's show the classification report with all the metrics
evaluate_model_performance(gs.best_estimator_, X_test, y_test)
# Out:
# Accuracy: 0.6082522748666458
# Precision: 0.7644483014306949
# Recall: 0.6082522748666458
# F1 Score: 0.660128911715179
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.17      0.60      0.26      1202
#    operating       0.88      0.65      0.75     10177
#      success       0.40      0.28      0.33      1369
#
#     accuracy                           0.61     12748
#    macro avg       0.48      0.51      0.45     12748
# weighted avg       0.76      0.61      0.66     12748

# %% [markdown]
# # ENSEMBLE NO GRID SEARCH

# %%
import warnings
warnings.simplefilter("ignore")

from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# create the individual models
clf1 = RandomForestClassifier(random_state=42)
clf2 = SVC(probability=True)  # probability calculation
clf3 = LogisticRegression()

# create the ensemble model
eclf = VotingClassifier(estimators=[('rf', clf1), ('svc', clf2), ('lr', clf3)], voting='soft')

eclf.fit(X_resampled, y_resampled)

print("Voting Classifier Results:")
vc_results = evaluate_model_performance(eclf, X_test, y_test)
# Out:
# Voting Classifier Results:
# Accuracy: 0.6481016630059617
# Precision: 0.7557165487590817
# Recall: 0.6481016630059617
# F1 Score: 0.6855748920754581
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.21      0.36      0.26      1202
#    operating       0.88      0.69      0.77     10177
#      success       0.29      0.59      0.39      1369
#
#     accuracy                           0.65     12748
#    macro avg       0.46      0.54      0.48     12748
# weighted avg       0.76      0.65      0.69     12748

# %%
np.set_printoptions(threshold=np.inf)
y_pred = eclf.predict(X_test)
y_pred
# Out:
# array(['operating', 'fail', 'operating', 'success', 'success', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'fail', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'success', 'fail',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'success', 'success', 'operating',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'operating', 'success', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'fail', 'success', 'success', 'operating',
#        'operating', 'operating', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'fail', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'success',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'fail',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'success', 'success', 'success', 'operating', 'success',
#        'operating', 'success', 'success', 'fail', 'operating', 'success',
#        'success', 'fail', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'fail', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'fail', 'success', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating', 'fail',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'success', 'success', 'fail',
#        'operating', 'success', 'success', 'success', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'success', 'operating', 'fail', 'fail', 'operating', 'success',
#        'fail', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'fail', 'operating', 'fail', 'success',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'fail', 'operating', 'fail',
#        'success', 'success', 'fail', 'fail', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'fail', 'fail', 'success',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating', 'fail',
#        'success', 'operating', 'operating', 'fail', 'operating',
#        'success', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'fail', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'fail', 'fail', 'fail', 'success', 'success',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'operating', 'success', 'fail', 'success', 'operating',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'fail', 'success', 'fail',
#        'operating', 'operating', 'fail', 'success', 'fail', 'operating',
#        'success', 'operating', 'success', 'success', 'operating',
#        'success', 'success', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'operating', 'success', 'fail', 'operating', 'operating',
#        'success', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'fail', 'fail', 'operating', 'operating', 'success', 'success',
#        'success', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'success', 'fail',
#        'success', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'success', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'success', 'fail', 'operating', 'fail', 'operating',
#        'success', 'operating', 'fail', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'success', 'fail',
#        'fail', 'operating', 'operating', 'fail', 'operating', 'fail',
#        'success', 'operating', 'fail', 'success', 'operating', 'success',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating', 'fail',
#        'success', 'success', 'operating', 'success', 'success', 'fail',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'fail', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'fail', 'operating', 'operating',
#        'success', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'fail', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'success', 'fail', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'fail', 'fail', 'operating', 'success',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'success', 'success', 'operating', 'operating', 'operating',
#        'operating', 'success', 'fail', 'operating', 'success', 'success',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'success', 'success', 'success', 'operating', 'success', 'success',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'success', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'success', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'fail', 'fail', 'operating', 'fail', 'success', 'operating',
#        'success', 'fail', 'operating', 'fail', 'operating', 'fail',
#        'operating', 'success', 'success', 'operating', 'success',
#        'success', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'success', 'fail',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'fail', 'success', 'fail', 'fail', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'success', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'fail', 'success', 'fail', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'success', 'operating', 'operating', 'fail', 'fail',
#        'success', 'success', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'fail', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'success', 'fail', 'success', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'fail', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'success', 'fail', 'success', 'operating', 'operating',
#        'operating', 'success', 'success', 'operating', 'success',
#        'operating', 'fail', 'success', 'operating', 'success', 'fail',
#        'success', 'operating', 'success', 'fail', 'operating',
#        'operating', 'operating', 'success', 'operating', 'success',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'fail', 'success', 'operating',
#        'operating', 'operating', 'success', 'operating', 'success',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'fail', 'success', 'operating', 'fail', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'fail', 'success', 'operating', 'fail', 'success', 'operating',
#        'fail', 'operating', 'success', 'operating', 'success',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'success', 'operating', 'fail', 'operating', 'success',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'fail', 'operating', 'success', 'fail', 'operating',
#        'success', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'fail', 'operating', 'operating',
#        'success', 'success', 'operating', 'operating', 'success', 'fail',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'fail', 'success', 'operating', 'fail', 'fail',
#        'operating', 'success', 'success', 'fail', 'operating',
#        'operating', 'success', 'operating', 'success', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'success', 'operating', 'operating', 'success',
#        'operating', 'fail', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'success', 'success', 'fail', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'success', 'fail', 'fail', 'fail',
#        'success', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'success', 'success', 'operating', 'success',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'fail', 'operating', 'operating', 'success', 'operating',
#        'success', 'fail', 'operating', 'operating', 'success', 'success',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'success', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'success', 'operating', 'success', 'success',
#        'success', 'fail', 'operating', 'success', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'success', 'success', 'operating', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'fail', 'operating', 'fail', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'success', 'operating', 'success', 'operating', 'fail', 'success',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'success', 'operating', 'success', 'operating', 'fail', 'fail',
#        'success', 'operating', 'success', 'operating', 'fail',
#        'operating', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'operating', 'fail', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'success', 'operating', 'operating', 'operating',
#        'fail', 'success', 'operating', 'operating', 'success',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'success', 'fail', 'operating', 'success', 'success', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'fail', 'operating', 'fail',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'success',
#        'fail', 'fail', 'operating', 'operating', 'operating', 'operating',
#        'success', 'fail', 'operating', 'success', 'operating', 'success',
#        'fail', 'success', 'operating', 'fail', 'success', 'operating',
#        'fail', 'success', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'fail', 'success', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'success', 'fail', 'operating', 'operating', 'success', 'success',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'success', 'success', 'operating',
#        'success', 'success', 'operating', 'success', 'success',
#        'operating', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'success', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'success', 'fail', 'operating', 'operating', 'fail',
#        'operating', 'fail', 'operating', 'operating', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'success', 'operating', 'success',
#        'operating', 'fail', 'fail', 'operating', 'operating', 'success',
#        'operating', 'fail', 'operating', 'success', 'operating',
#        'success', 'operating', 'success', 'fail', 'operating',
#        'operating', 'operating', 'success', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'success', 'fail', 'operating', 'success', 'success', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'success', 'success', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'success', 'success', 'operating',
#        'fail', 'operating', 'operating', 'fail', 'operating', 'fail',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'success', 'success', 'fail',
#        'operating', 'operating', 'fail', 'success', 'fail', 'fail',
#        'fail', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'success', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'fail', 'operating', 'operating', 'fail', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'operating', 'fail', 'fail',
#        'success', 'success', 'operating', 'operating', 'fail',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'fail', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'success', 'success', 'operating', 'success',
#        'operating', 'success', 'operating', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'success',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'fail', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'fail', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'success', 'fail', 'fail',
#        'success', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'fail', 'operating', 'operating', 'operating', 'success',
#        'operating', 'success', 'operating', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'success', 'success', 'fail', 'operating',
#        'operating', 'fail', 'success', 'fail', 'success', 'operating',
#        'success', 'operating', 'operating', 'success', 'fail',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'success', 'success', 'operating', 'success', 'operating', 'fail',
#        'fail', 'success', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'fail', 'success',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'success',
#        'fail', 'operating', 'success', 'success', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'fail', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'success', 'operating', 'success', 'fail', 'operating', 'success',
#        'fail', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'fail', 'operating', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'fail', 'success', 'success', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'success', 'fail', 'fail', 'fail', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'fail', 'operating',
#        'operating', 'fail', 'operating', 'success', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'success', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'success', 'operating', 'fail',
#        'fail', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'success', 'fail',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'fail', 'operating', 'success', 'operating', 'fail',
#        'fail', 'operating', 'operating', 'operating', 'operating',
#        'success', 'fail', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'success', 'operating', 'success', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating', 'fail',
#        'operating', 'success', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'fail', 'success', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'fail', 'fail', 'fail', 'success', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'success', 'fail',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'operating', 'operating', 'operating', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'success', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'success', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'fail', 'success', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'success', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'operating', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'success', 'fail', 'operating', 'success', 'fail',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'success', 'operating', 'fail',
#        'fail', 'fail', 'operating', 'fail', 'operating', 'fail',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'fail', 'fail', 'operating', 'success', 'fail', 'operating',
#        'operating', 'operating', 'success', 'fail', 'success',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'operating',
#        'success', 'fail', 'operating', 'fail', 'operating', 'success',
#        'fail', 'operating', 'success', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success', 'fail',
#        'operating', 'operating', 'fail', 'success', 'operating',
#        'operating', 'fail', 'operating', 'fail', 'operating', 'operating',
#        'success', 'fail', 'fail', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'success', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'fail', 'success', 'operating', 'success',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'success', 'success', 'operating',
#        'operating', 'fail', 'fail', 'operating', 'fail', 'fail',
#        'success', 'success', 'operating', 'operating', 'fail', 'success',
#        'success', 'operating', 'operating', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'fail', 'operating', 'operating', 'success',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'fail', 'operating', 'fail', 'success', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'success',
#        'success', 'operating', 'fail', 'success', 'fail', 'operating',
#        'success', 'success', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'success', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'fail', 'success', 'operating', 'success', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating', 'fail',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'success', 'success', 'operating',
#        'operating', 'fail', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'success', 'success', 'fail',
#        'operating', 'fail', 'fail', 'operating', 'success', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'fail', 'success', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'fail', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'success', 'operating', 'fail', 'operating', 'success',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'fail', 'operating', 'fail', 'success', 'success', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'success', 'operating', 'success',
#        'fail', 'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'fail', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'success', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'fail', 'success', 'fail', 'operating', 'success',
#        'fail', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'success', 'success', 'success',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'success', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'fail', 'success', 'fail', 'success', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'fail', 'success', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'success', 'success', 'operating', 'operating', 'operating',
#        'fail', 'fail', 'fail', 'operating', 'operating', 'operating',
#        'success', 'success', 'operating', 'operating', 'success',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'success', 'success', 'success',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'operating', 'success', 'operating', 'success',
#        'operating', 'operating', 'success', 'fail', 'success',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'success', 'success', 'operating', 'success', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'operating', 'fail', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'success', 'success', 'success', 'operating',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'fail', 'operating', 'success', 'success', 'success',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'fail', 'success', 'success', 'operating',
#        'fail', 'operating', 'success', 'operating', 'operating',
#        'success', 'fail', 'operating', 'fail', 'success', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'success', 'success', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'success', 'operating', 'fail', 'operating', 'success',
#        'operating', 'operating', 'fail', 'success', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'success', 'fail', 'operating', 'operating', 'fail',
#        'fail', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'fail', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'fail', 'operating', 'operating',
#        'fail', 'success', 'success', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'fail', 'operating', 'operating', 'success', 'operating',
#        'success', 'operating', 'success', 'fail', 'success', 'operating',
#        'operating', 'success', 'success', 'operating', 'success',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'fail',
#        'operating', 'fail', 'success', 'operating', 'operating', 'fail',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'success', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'fail', 'fail', 'success', 'operating', 'fail',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'fail', 'success',
#        'operating', 'operating', 'operating', 'fail', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'success',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'success',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'success', 'operating',
#        'operating', 'success', 'fail', 'fail', 'operating', 'operating',
#        'fail', 'fail', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'fail', 'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'fail',
#        'operating', 'operating', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'fail', 'fail',
#        'success', 'fail', 'success', 'operating', 'success', 'fail',
#        'success', 'success', 'operating', 'operating', 'fail',
#        'operating', 'fail', 'fail', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'fail', 'success', 'operating', 'operating', 'fail', 'operating',
#        'success', 'operating', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'success', 'success', 'fail', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'success', 'operating', 'fail', 'operating', 'operating',
#        'success', 'fail', 'fail', 'operating', 'operating', 'operating',
#        'fail', 'success', 'success', 'fail', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'fail', 'success',
#        'fail', 'fail', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'success', 'success', 'success', 'fail',
#        'operating', 'operating', 'success', 'success', 'fail', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'fail', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
# ...
#        'fail', 'operating', 'operating', 'operating', 'fail', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'fail', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'success', 'fail', 'fail',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'success', 'operating',
#        'success', 'success', 'operating', 'operating', 'fail',
#        'operating', 'fail', 'fail', 'operating', 'success', 'fail',
#        'operating', 'fail', 'operating', 'fail', 'fail', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'fail', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'fail', 'success', 'fail', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'fail', 'operating', 'success',
#        'operating', 'operating', 'success', 'fail', 'operating',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'success', 'fail', 'success', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'success', 'fail', 'fail', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'fail', 'success',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'fail', 'fail', 'success', 'fail', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'fail', 'fail', 'success',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'success', 'fail', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'success', 'operating', 'fail', 'success', 'fail',
#        'fail', 'fail', 'operating', 'success', 'success', 'success',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'success', 'success', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'fail',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'success', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'success', 'success', 'fail', 'success', 'operating', 'operating',
#        'success', 'fail', 'fail', 'success', 'success', 'success',
#        'operating', 'operating', 'success', 'success', 'fail', 'fail',
#        'success', 'fail', 'success', 'success', 'operating', 'fail',
#        'fail', 'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'success', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'fail', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'success', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'fail', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'fail', 'fail', 'success',
#        'operating', 'success', 'success', 'operating', 'fail', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'success', 'fail', 'operating', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'success', 'success', 'fail', 'fail', 'success', 'operating',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'success', 'success',
#        'operating', 'fail', 'success', 'operating', 'operating',
#        'operating', 'fail', 'success', 'fail', 'operating', 'success',
#        'success', 'fail', 'operating', 'success', 'success', 'operating',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'success', 'operating', 'operating', 'operating',
#        'success', 'fail', 'success', 'fail', 'operating', 'operating',
#        'fail', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'fail', 'success', 'operating', 'fail', 'fail', 'operating',
#        'operating', 'fail', 'success', 'success', 'operating',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'operating', 'operating', 'fail', 'fail', 'success',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'success', 'success', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'success', 'operating', 'fail', 'operating', 'fail',
#        'success', 'fail', 'fail', 'fail', 'operating', 'operating',
#        'success', 'fail', 'success', 'operating', 'operating', 'fail',
#        'fail', 'operating', 'operating', 'success', 'fail', 'fail',
#        'operating', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'success', 'fail', 'operating',
#        'operating', 'success', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'fail', 'success', 'success', 'operating', 'operating',
#        'operating', 'success', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'fail', 'success', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'operating', 'operating', 'fail', 'operating',
#        'success', 'operating', 'success', 'operating', 'success',
#        'operating', 'success', 'operating', 'success', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'success', 'operating', 'operating', 'success', 'fail',
#        'operating', 'success', 'operating', 'fail', 'success', 'success',
#        'fail', 'operating', 'operating', 'fail', 'success', 'operating',
#        'fail', 'operating', 'operating', 'fail', 'operating', 'success',
#        'success', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'success', 'success', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'fail', 'operating', 'success', 'success', 'fail',
#        'success', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'fail', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'operating', 'fail', 'operating', 'fail', 'operating',
#        'fail', 'operating', 'operating', 'fail', 'fail', 'success',
#        'operating', 'fail', 'operating', 'operating', 'success',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'fail', 'fail', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'success', 'fail', 'fail', 'success', 'fail',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'success', 'operating',
#        'operating', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'fail', 'operating',
#        'operating', 'success', 'operating', 'operating', 'fail',
#        'success', 'fail', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success', 'fail',
#        'success', 'operating', 'fail', 'fail', 'operating', 'success',
#        'fail', 'fail', 'operating', 'success', 'success', 'success',
#        'success', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'success', 'success', 'fail', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'operating',
#        'success', 'success', 'success', 'operating', 'success',
#        'operating', 'operating', 'operating', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'fail', 'operating', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'success', 'success',
#        'success', 'operating', 'operating', 'success', 'success',
#        'operating', 'fail', 'operating', 'fail', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'operating', 'success',
#        'operating', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'operating', 'success', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'operating',
#        'success', 'operating', 'fail', 'operating', 'success', 'success',
#        'fail', 'operating', 'success', 'operating', 'operating', 'fail',
#        'operating', 'operating', 'operating', 'fail', 'success', 'fail',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'fail', 'operating',
#        'operating', 'operating', 'operating', 'success', 'operating',
#        'operating', 'operating', 'fail', 'success', 'operating',
#        'operating', 'operating', 'operating', 'fail', 'success',
#        'success', 'success', 'fail', 'operating', 'success', 'operating',
#        'operating', 'operating', 'success', 'operating', 'fail',
#        'operating', 'fail', 'fail', 'operating', 'operating', 'success',
#        'operating', 'success', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success', 'operating', 'operating',
#        'success', 'operating', 'operating', 'operating', 'operating',
#        'operating', 'operating', 'success'], dtype=object)

# %% [markdown]
# # UPDATED ENSEMBLE WITH GRID SEARCH

# %% [markdown]
# # BAGGING

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# Define the RandomForestClassifier
rf = RandomForestClassifier(random_state=42)

# Define the hyperparameters for the RandomizedSearchCV
params = {'n_estimators': [50, 100, 200],
          'max_depth': [None, 5, 10],
          'min_samples_split': [2, 5]}

# Apply RandomizedSearchCV for hyperparameter tuning
random_search = RandomizedSearchCV(rf, param_distributions=params, cv=3, n_jobs=-1, n_iter=20, random_state=42)
random_search.fit(X_resampled, y_resampled)

print("Bagging Results:")
evaluate_model_performance(random_search.best_estimator_, X_test, y_test)
# Out:
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Bagging Results:
# Accuracy: 0.7020709130844054
# Precision: 0.7360720909331802
# Recall: 0.7020709130844054
# F1 Score: 0.7170658296436172
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.20      0.25      0.23      1202
#    operating       0.85      0.79      0.82     10177
#      success       0.32      0.43      0.37      1369
#
#     accuracy                           0.70     12748
#    macro avg       0.46      0.49      0.47     12748
# weighted avg       0.74      0.70      0.72     12748

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# Create a BaggingClassifier with KNeighborsClassifier as the base estimator
bagging = BaggingClassifier(KNeighborsClassifier(), max_samples=0.5, max_features=0.5)

# Define a dictionary of parameters for GridSearchCV
param_grid = {'n_estimators': [10, 20, 50],
              'base_estimator__n_neighbors': [3, 5, 7],
              'max_samples': [0.5, 1.0],
              'max_features': [0.5, 1.0]}

# Setup GridSearchCV with the ensemble model and parameter grid
grid = GridSearchCV(estimator=bagging, param_grid=param_grid, cv=10, scoring='accuracy', refit=True)

# Train the ensemble model
grid = grid.fit(X_resampled, y_resampled)

# Print the best parameters and estimator
print('Best estimator: {}\nBest params: {}'.format(grid.best_estimator_, grid.best_params_))

# Evaluate performance of the model trained with best parameters
print("Performance of the model with best parameters:")
evaluate_model_performance(grid.best_estimator_, X_test, y_test)
# Out:
# Best estimator: BaggingClassifier(estimator=KNeighborsClassifier(n_neighbors=3),
#                   n_estimators=50)
# Best params: {'base_estimator__n_neighbors': 3, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50}
# Performance of the model with best parameters:
# Accuracy: 0.5982899278318168
# Precision: 0.7238349049525943
# Recall: 0.5982899278318168
# F1 Score: 0.6439922933351583
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.17      0.36      0.23      1202
#    operating       0.86      0.65      0.74     10177
#      success       0.23      0.42      0.30      1369
#
#     accuracy                           0.60     12748
#    macro avg       0.42      0.48      0.42     12748
# weighted avg       0.72      0.60      0.64     12748

# %% [markdown]
# # BOOSTING

# %%
import warnings
warnings.simplefilter("ignore")
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV

gb = GradientBoostingClassifier(random_state=42)

params = {'n_estimators': [50, 100, 200],
          'max_depth': [3, 5, 7],
          'learning_rate': [0.01, 0.1, 1]}

random_search = RandomizedSearchCV(gb, param_distributions=params, cv=3, n_jobs=-1, n_iter=20, random_state=42)
random_search.fit(X_resampled, y_resampled)


print("BOOSTING Results:")
evaluate_model_performance(random_search.best_estimator_, X_test, y_test)
# Out:
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BOOSTING Results:
# Accuracy: 0.7311735174144964
# Precision: 0.7263904974577458
# Recall: 0.7311735174144964
# F1 Score: 0.728608723620627
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.24      0.24      0.24      1202
#    operating       0.84      0.85      0.84     10177
#      success       0.33      0.29      0.31      1369
#
#     accuracy                           0.73     12748
#    macro avg       0.47      0.46      0.46     12748
# weighted avg       0.73      0.73      0.73     12748

# %% [markdown]
# # STACKING

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

estimators = [
    ('dt', DecisionTreeClassifier(max_depth=5, min_samples_split=2, random_state=42)),
    ('knn', KNeighborsClassifier(n_neighbors=5))
]

stacking = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression(), cv=3)
stacking.fit(X_resampled, y_resampled)


print("STACKING Results:")
evaluate_model_performance(stacking, X_test, y_test)
# Out:
# STACKING Results:
# Accuracy: 0.6226074678380923
# Precision: 0.7302716883137017
# Recall: 0.6226074678380923
# F1 Score: 0.663197291396979
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.18      0.35      0.23      1202
#    operating       0.86      0.68      0.76     10177
#      success       0.25      0.42      0.32      1369
#
#     accuracy                           0.62     12748
#    macro avg       0.43      0.48      0.44     12748
# weighted avg       0.73      0.62      0.66     12748

# %% [markdown]
# # VOTING

# %%
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score
import warnings
warnings.simplefilter("ignore")

# create the individual models
rf = RandomForestClassifier(random_state=42)
dt = DecisionTreeClassifier(random_state=42)
knn = KNeighborsClassifier()

# create the ensemble model
eclf = VotingClassifier(estimators=[('rf', rf), ('dt', dt), ('knn', knn)], voting='soft')

# define a dictionary of parameters for RandomizedSearchCV
params = {'rf__n_estimators': [50, 100],
          'rf__max_depth': [None, 5],
          'rf__min_samples_split': [2, 5],
          'dt__max_depth': [None, 5],
          'dt__min_samples_split': [2, 5],
          'knn__n_neighbors': [3, 5],
          'knn__weights': ['uniform', 'distance']}

# setup randomized search with the ensemble model and parameter grid
random_search = RandomizedSearchCV(estimator=eclf, param_distributions=params, cv=3, verbose=3, n_jobs=-1, n_iter=10)

# train the ensemble model
random_search = random_search.fit(X_resampled, y_resampled)

# Print the best parameters
print("Best Parameters:")
print(random_search.best_params_)



print("Performance of the model with best parameters:")
evaluate_model_performance(random_search.best_estimator_, X_test, y_test)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/mac/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Best Parameters:
# {'rf__n_estimators': 50, 'rf__min_samples_split': 2, 'rf__max_depth': None, 'knn__weights': 'distance', 'knn__n_neighbors': 5, 'dt__min_samples_split': 5, 'dt__max_depth': None}
# Performance of the model with best parameters:
# Accuracy: 0.67579228114214
# Precision: 0.7243236614944548
# Recall: 0.67579228114214
# F1 Score: 0.6968670580839567
# Classification Report:
#                precision    recall  f1-score   support
#
#         fail       0.19      0.28      0.23      1202
#    operating       0.85      0.76      0.80     10177
#      success       0.27      0.37      0.31      1369
#
#     accuracy                           0.68     12748
#    macro avg       0.44      0.47      0.45     12748
# weighted avg       0.72      0.68      0.70     12748
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.835 total time=  18.4s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.849 total time=  19.3s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.850 total time=  22.5s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=100;, score=0.772 total time=  14.4s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=100;, score=0.800 total time=  14.2s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.786 total time=  15.0s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.816 total time=   8.9s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.802 total time=   9.6s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.805 total time=  20.6s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.840 total time=  22.5s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.821 total time=  13.9s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=100;, score=0.805 total time=  14.2s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.837 total time=  19.8s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.807 total time=   9.8s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.796 total time=  11.4s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.803 total time=  37.3s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.846 total time=  14.6s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.815 total time=  10.0s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.782 total time=   8.9s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.787 total time=   9.2s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.843 total time=  19.9s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.800 total time=  19.3s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.838 total time=  20.0s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.786 total time=  17.5s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.802 total time=  11.6s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.782 total time=  10.2s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.820 total time=   8.6s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.801 total time=   9.2s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.801 total time=  20.5s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.787 total time=   9.2s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.756 total time=  11.8s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.827 total time=  20.2s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.817 total time=  16.4s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.829 total time=  15.2s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=100;, score=0.801 total time=  13.9s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.815 total time=   8.9s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.795 total time=  19.0s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.773 total time=   9.1s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.804 total time=   9.8s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.793 total time=  11.5s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.844 total time=  36.3s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.857 total time=  14.8s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.781 total time=  14.4s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.773 total time=   9.3s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.834 total time=  18.6s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.812 total time=   8.6s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.768 total time=  10.1s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.817 total time=  19.8s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.841 total time=  35.7s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=100;, score=0.787 total time=  14.0s
# [CV 1/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=100;, score=0.763 total time=  14.7s
# [CV 2/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.817 total time=  14.6s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=2, rf__n_estimators=50;, score=0.806 total time=   8.3s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.823 total time=  18.4s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.838 total time=  19.2s
# [CV 1/3] END dt__max_depth=5, dt__min_samples_split=5, knn__n_neighbors=5, knn__weights=distance, rf__max_depth=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.821 total time=  23.4s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=50;, score=0.820 total time=  10.0s
# [CV 3/3] END dt__max_depth=None, dt__min_samples_split=5, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.815 total time=  12.9s
# [CV 2/3] END dt__max_depth=None, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=uniform, rf__max_depth=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.838 total time=  18.2s
# [CV 3/3] END dt__max_depth=5, dt__min_samples_split=2, knn__n_neighbors=3, knn__weights=distance, rf__max_depth=5, rf__min_samples_split=5, rf__n_estimators=100;, score=0.802 total time=  10.9s

# %% [markdown]
# # SAVING THE BEST MODEL

# %%
import pickle

# %%
data = {"model": random_search.best_estimator_, "le_country_name": le_country_name, "le_main_category": le_main_category, "le_location":le_location}
with open('boosting_ensemble.pkl', 'wb') as file:
    pickle.dump(data, file)
